# %% [markdown]
# ## Worksheet Flow
# <center>
# 1) 알고리즘 선택  (SVM, KNN, decisiontree, randomforest, ensemble boosting) <br>
#                                 ↓<br>
# 2) 분류 및 회귀 중 선택 후 데이터 준비 및 생성 - csv 파일 꼭 열어보면서 확인할 것 <br>
#                                 ↓<br>
# 3) 머신러닝 모델 개발 및 평가 진행 <br>
#                                 ↓<br>
# 4) 최종 평가 성능 공유 (가장 성능이 좋고 선택한 데이터에 적합한한 알고리즘 모델은 어떤걸까요?!) </center>

# %% [markdown]
# ### 머신러닝 모델 개발 및 평가 단계 (전체 흐름도) <br>
# <center>
# [1. 데이터 준비 및 X,y 생성]<br>
#         ↓<br>
# [2. 학습/검증용 데이터 분할 (Train/Test Split)]<br>
#         ↓<br>
# [3. 전처리 및 모델 pipeline 만들기]<br>
# [4. 하이퍼파라미터 탐색 및 모델 튜닝 (GridSearchCV)]<br>
#         ↓<br>
# [5. 모델 학습 (Fit)]<br>
#         ↓<br>
# [6. 학습 결과 평가 (Best Params, Score)]<br>
#         ↓<br>
# [7. 테스트셋 최종 평가 (Best Estimator Predict)]
# </center>

# %% [markdown]
# #### 1. 데이터 준비 및 X,y 생성

# %%
cancer
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.compose import ColumnTransformer


cancer = pd.read_csv("data\Cancer_Data.csv")


X = cancer.drop(columns= "diagnosis")
X = X.drop(columns= "Unnamed: 32")
y = LabelEncoder().fit_transform(cancer["diagnosis"])
# y = cancer["diagnosis"]
# Out:
# <>:6: SyntaxWarning: invalid escape sequence '\C'
# <>:6: SyntaxWarning: invalid escape sequence '\C'
# C:\Users\Playdata\AppData\Local\Temp\ipykernel_1560\3861251851.py:6: SyntaxWarning: invalid escape sequence '\C'
#   cancer = pd.read_csv("data\Cancer_Data.csv")

# %% [markdown]
# #### 2. 학습/검증용 데이터 분할 (Train/Test Split)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

X.shape, y.shape, X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((569, 31), (569,), (426, 31), (143, 31), (426,), (143,))

# %% [markdown]
# #### 3. 전처리 및 모델 pipeline 만들기 <br> 4. 하이퍼파라미터 탐색 및 모델 튜닝 (GridSearchCV)

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer

pipeline = Pipeline([
	("imputer", SimpleImputer(strategy="mean")),
	("scaler", StandardScaler()),
	("model", DecisionTreeClassifier(random_state=42))
])

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.tree import DecisionTreeClassifier

params = {
	"model__max_depth" : range(1,13),
	"model__max_leaf_nodes" : range(10,56),
	"model__min_samples_leaf" : range(10, 1001, 50),
	"model__max_features" : range(1,13)
}

gs = RandomizedSearchCV(
	pipeline,
	params,
	n_iter = 50,
	scoring = "accuracy",
	cv = 5	
)

# %% [markdown]
# #### 5. 모델 학습 (Fit)

# %%
gs.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('imputer', SimpleImputer()),
#                                              ('scaler', StandardScaler()),
#                                              ('model',
#                                               DecisionTreeClassifier(random_state=42))]),
#                    n_iter=50,
#                    param_distributions={'model__max_depth': range(1, 13),
#                                         'model__max_features': range(1, 13),
#                                         'model__max_leaf_nodes': range(10, 56),
#                                         'model__min_samples_leaf': range(10, 1001, 50)},
#                    scoring='accuracy')

# %% [markdown]
# #### 6. 학습 결과 평가 (Best Params, Score)

# %%
gs.best_params_, gs.best_score_
# Out:
# ({'model__min_samples_leaf': 10,
#   'model__max_leaf_nodes': 32,
#   'model__max_features': 2,
#   'model__max_depth': 12},
#  np.float64(0.9154582763337894))

# %% [markdown]
# #### 7. 테스트셋 최종 평가 (Best Estimator Predict)

# %% [markdown]
# gs.best_estimator_

# %%
gs.best_estimator_
# Out:
# Pipeline(steps=[('imputer', SimpleImputer()), ('scaler', StandardScaler()),
#                 ('model',
#                  DecisionTreeClassifier(max_depth=12, max_features=2,
#                                         max_leaf_nodes=32, min_samples_leaf=10,
#                                         random_state=42))])

# %%
from metrics import print_binary_classification_metrics

pred_train = gs.predict(X_train)
pred_train_proba = gs.predict_proba(X_train)


print_binary_classification_metrics(y_train, pred_train)
# Out:
# 정확도: 0.9413145539906104
# 재현율: 0.9050632911392406
# 정밀도: 0.934640522875817
# F1 점수: 0.9196141479099679

# %%
y_train.shape
# Out:
# (426,)

# %%
X_pred = gs.predict(X_test)
