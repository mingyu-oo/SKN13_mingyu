# %% [markdown]
# # Gensim 패키지
# - Python으로 작성된 오픈 소스 라이브러리로, 자연어 처리와 관련된 다양한 기능을 제공한다.
# - 주요 기능
#     - **Word Embeddings**
#         - word2vec, fastext, doc2vec 등 다양한 word embedding 모델을 제공
#     - **토픽 모델링 (Topic Modeling)**
#         - LDA등 문장의 주제를 파악하는 모델 제공
#     - **텍스트/word 유사도 계산**
#     - **문서 군집화**
#         - 비슷한 주제의 문서들을 군집화.
#     - 다양한 dataset과 pretrained model 제공
#         - https://github.com/piskvorky/gensim-data
# - https://radimrehurek.com/gensim/

# %% [markdown]
# ## 설치
# - `pip install gensim`

# %%
# %pip install gensim
# Out:
# Requirement already satisfied: gensim in c:\users\playdata\miniconda3\envs\dl\lib\site-packages (4.3.3)
# Requirement already satisfied: numpy<2.0,>=1.18.5 in c:\users\playdata\miniconda3\envs\dl\lib\site-packages (from gensim) (1.26.4)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in c:\users\playdata\miniconda3\envs\dl\lib\site-packages (from gensim) (1.13.1)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\playdata\miniconda3\envs\dl\lib\site-packages (from gensim) (7.1.0)
# Requirement already satisfied: wrapt in c:\users\playdata\miniconda3\envs\dl\lib\site-packages (from smart-open>=1.8.1->gensim) (1.17.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Word2Vec 학습
#
# - gensim.models.Word2Vec
# - 주요 파라미터
#     - sentences
#         -  학습에 사용할 문서의 리스트. 각 문서의 단어들을 리스트로 묶고 그 문서들을 리스트로 묶은 중첩 리스트.
#         - 예시: \[\['word1', 'word2', 'word3'], \['word4', 'word5']]
#     - vector_size
#         -  embedding vector 크기. 기본값: 100
#     - window
#         -  context window 크기. 중심단어를 기준으로 좌우 몇개의 단어를 확인하는지 크기. 기본값: 5
#     - min_count
#         - 이 설정보다 낮은 빈도로 등장하는 단어는 무시한다. 데이터 노이즈를 줄이는데 도움이된다. 기본값: 5
#     - sg
#         - 모델 아키텍처 결정.
#         - `0`: CBOW, `1`: Skip-gram. 기본값: 0
#     - epochs
#         - epochs 수 설정. 기본값: 5
#     - alpha
#         - initial leaning rate. 기본값: 0.025
#     - min_alpha
#         - 최소 learning rate. 기본값: 0.0001
#         - epoch 마다 learning rate를 alpha 에서 min_alpha 까지 선형적으로 줄여나간다.
#     - workers
#         -  사용 Thread 수. 기본값: 3

# %% [markdown]
# ## 학습(Train)
# 1. Word2Vec 의 initializer에 sentences를 넣어 한번에 학습한다.
# 2. Word2Vec 클래스에 학습 설정을 하고 `train()` 메소드를 이용해 학습한다.
#     - epoch 단위로 작업을 할 경우 사용

# %%
# 샘플 텍스트 데이터
sentences = [
    "Natural language processing is an exciting field of study",
    "Word embeddings are a type of word representation",
    "Gensim is a powerful library for text processing",
    "Word2Vec creates vector representations of words", 
    "Gensim runs on Linux, Windows and OS X, as well as any other platform that supports Python and NumPy."
    "All Gensim source code is hosted on Github under the GNU LGPL license, maintained by its open source community.",
    "For commercial arrangements, see Business Support.",
    "Gensim can process arbitrarily large corpora, using data-streamed algorithms.",
    "There are no \"dataset must fit in RAM\" limitations."
]

# %%
import re
import nltk
def tokenizer(docs):
	# 소문자로 모두 변환
	# 알파벳, 순자, _를 제외한 모든 문자들을 제거
	# 단어(어절) 단위 토큰화
	return [ nltk.word_tokenize(re.sub(r"[^\w\s]", " ", doc.lower())) for doc in docs]

# [^\w] - \w를 제외한 나머지 ^들을 찾아라

# %%
import re
[nltk.word_tokenize(re.sub(r"[^\w]", "", doc.lower())) for doc in sentences]
# Out:
# [['naturallanguageprocessingisanexcitingfieldofstudy'],
#  ['wordembeddingsareatypeofwordrepresentation'],
#  ['gensimisapowerfullibraryfortextprocessing'],
#  ['word2veccreatesvectorrepresentationsofwords'],
#  ['gensimrunsonlinuxwindowsandosxaswellasanyotherplatformthatsupportspythonandnumpyallgensimsourcecodeishostedongithubunderthegnulgpllicensemaintainedbyitsopensourcecommunity'],
#  ['forcommercialarrangementsseebusinesssupport'],
#  ['gensimcanprocessarbitrarilylargecorporausingdatastreamedalgorithms'],
#  ['therearenodatasetmustfitinramlimitations']]

# %%
tokens = tokenizer(sentences)
tokens
# Out:
# [['natural',
#   'language',
#   'processing',
#   'is',
#   'an',
#   'exciting',
#   'field',
#   'of',
#   'study'],
#  ['word', 'embeddings', 'are', 'a', 'type', 'of', 'word', 'representation'],
#  ['gensim', 'is', 'a', 'powerful', 'library', 'for', 'text', 'processing'],
#  ['word2vec', 'creates', 'vector', 'representations', 'of', 'words'],
#  ['gensim',
#   'runs',
#   'on',
#   'linux',
#   'windows',
#   'and',
#   'os',
#   'x',
#   'as',
#   'well',
#   'as',
#   'any',
#   'other',
#   'platform',
#   'that',
#   'supports',
#   'python',
#   'and',
#   'numpy',
#   'all',
#   'gensim',
#   'source',
#   'code',
#   'is',
#   'hosted',
#   'on',
#   'github',
#   'under',
#   'the',
#   'gnu',
#   'lgpl',
#   'license',
#   'maintained',
#   'by',
#   'its',
#   'open',
#   'source',
#   'community'],
#  ['for', 'commercial', 'arrangements', 'see', 'business', 'support'],
#  ['gensim',
#   'can',
#   'process',
#   'arbitrarily',
#   'large',
#   'corpora',
#   'using',
#   'data',
#   'streamed',
#   'algorithms'],
#  ['there', 'are', 'no', 'dataset', 'must', 'fit', 'in', 'ram', 'limitations']]

# %%
# train
## Word2Vec 객체를 생성 : 학습data, epoch -> 객체 생성할 때 모델을 학습, 학습결과 모델을 반환.
from gensim.models import Word2Vec
import os

model1 = Word2Vec(
	sentences=tokens,	# 학습 시킬 data
	vector_size=10,		# embedding vector의 차원(한개 단어에서 몇개 feature를 추출할지)
	window=2,			# window size (주변 단어의 개수)
	min_count=1,
	epochs=10,
	workers=os.cpu_count()	# 병렬처리 개수
)

# %%
# 학습data, epoch를 설정하지 않음 -> 학습되지 않은 모델 반환
model2 = Word2Vec(
	vector_size=10,
	window=2,
	min_count=1,
	workers=os.cpu_count()
)
# model에 vocab을 설정
model2.build_vocab(tokens)
# 학습
epoch = 10
for e in range(epoch):
	model2.train(
		tokens,		# 학습data
		total_examples=model2.corpus_count,		# 학습data(문서) 개수
		epochs=1,
		compute_loss=True
	)
	loss = model2.get_latest_training_loss()
	print(f"{e} epoch loss :  {loss}")
# Out:
# 0 epoch loss :  151.93861389160156
# 1 epoch loss :  121.71185302734375
# 2 epoch loss :  109.64387512207031
# 3 epoch loss :  135.7916259765625
# 4 epoch loss :  176.20217895507812
# 5 epoch loss :  154.9056396484375
# 6 epoch loss :  150.0056915283203
# 7 epoch loss :  122.36213684082031
# 8 epoch loss :  143.60386657714844
# 9 epoch loss :  166.28038024902344

# %% [markdown]
# ## 학습 후 결과 조회
#
# - **KeyedVectors 조회**
#     - KeyedVectors는 단어와 vector를 매핑한 객체로 embedding vector를 이용한 다양한 조회를 지원한다.
#     - model.wv 로 조회해서 사용.
# - **Embedding Vector 조회**
#   - model.wv.vectors
# - **단어 목록 조회**
#     - model.wv.index_to_key, model.wv.key_to_index
# - **단어 벡터 조회**
#     - model.wv[word]: 특정 단어의 vector반환
# - **Vocab에 대상 단어가 있는지 확인**
#     - "대상단어" in model.wv
# - **유사단어들 찾기**
#     - model.wv.most_similar(word)
# - **단어간 유사도 비교**
#     - model.wv.similarity(word1, word2)
# - 유사도를 계산할 때 **코사인 유사도(Cosine Similarity)** 를 사용한다.

# %% [markdown]
# > # 코사인 유사도
# > - 두 벡터 간의 유사성을 측정하는 중요한 방법 중 하나.
# > - 코사인 유사도는 두 벡터 간의 코사인 각도를 이용하여 유사도를 계산한다. 이때 벡터의 **크기는 결과에 영향을 미치지 않고, 오직 방향만이 중요**하다.
# > ## 공식
# >
# > $$ similarity = cos(\theta) = \frac{A⋅B}{||A||\ ||B||} = \frac{\sum_{i=1}^{n}{A_i×B_i}}{\sqrt{\sum_{i=1}^{n}(A_i)^2}×\sqrt{\sum_{i=1}^{n}(B_i)^2}} $$
# >
# > ## 결과 해석
# >
# > - **값의 범위**: -1에서 1 사이의 값을 가집니다
# >   - 1: 두 벡터가 완전히 동일한 방향 (0도의 cosine 값)
# >   - 0: 두 벡터가 직교 (90도의 cosine 값)
# >   - -1: 두 벡터가 정반대 방향 (180도의 cosine 값)
# >
# > ![cosine_similarity](figures/gensim_consin_sim.png)
# >
# > ## Python 코사인 유사도 계산
# > ```python
# > from numpy import dot
# > from numpy.linalg import norm
# >
# > def cosine_similarity(A, B):
# >     return dot(A, B)/(norm(A)*norm(B))
# > ```

# %%
model1.wv	# KeyedVectors -> token-embedding vector

# %%
model1.wv.index_to_key	# vocab : token_id -> token(단어)
# Out:
# ['gensim',
#  'is',
#  'of',
#  'for',
#  'processing',
#  'source',
#  'on',
#  'as',
#  'word',
#  'are',
#  'a',
#  'and',
#  'words',
#  'runs',
#  'linux',
#  'windows',
#  'x',
#  'os',
#  'vector',
#  'well',
#  'any',
#  'other',
#  'representations',
#  'limitations',
#  'creates',
#  'word2vec',
#  'text',
#  'that',
#  'library',
#  'powerful',
#  'representation',
#  'type',
#  'embeddings',
#  'study',
#  'field',
#  'exciting',
#  'an',
#  'language',
#  'platform',
#  'supports',
#  'ram',
#  'data',
#  'support',
#  'can',
#  'process',
#  'arbitrarily',
#  'large',
#  'corpora',
#  'using',
#  'streamed',
#  'python',
#  'algorithms',
#  'there',
#  'no',
#  'dataset',
#  'must',
#  'fit',
#  'in',
#  'business',
#  'see',
#  'arrangements',
#  'commercial',
#  'numpy',
#  'all',
#  'code',
#  'hosted',
#  'github',
#  'under',
#  'the',
#  'gnu',
#  'lgpl',
#  'license',
#  'maintained',
#  'by',
#  'its',
#  'open',
#  'community',
#  'natural']

# %%
# 특정 단어의 embedding vector를 조회
model1.wv["gensim"]
# Out:
# array([-0.00524791,  0.00244228,  0.05116045,  0.09009441, -0.09281229,
#        -0.0712302 ,  0.06483191,  0.08985646, -0.05037782, -0.03772063],
#       dtype=float32)

# %%
# model1.wv["안녕"]
"안녕" in model1.wv, "gensim" in model1.wv
# Out:
# (False, True)

# %%
word = "안녕"
if word in model1.wv:
	print(model1.wv[word])
else:
	print("없는뎁쇼")
# Out:
# 없는뎁쇼

# %%
# 유사도 검사
model1.wv.most_similar("gensim")	# gensim과 가장 유사한 단어를 순서대로 10개를 반환.
# (단어, 유사도) 유사도 : -1 ~ 1
# Out:
# [('commercial', 0.7190989851951599),
#  ('embeddings', 0.7149730324745178),
#  ('platform', 0.670430600643158),
#  ('support', 0.6412696838378906),
#  ('using', 0.596753716468811),
#  ('is', 0.5443570613861084),
#  ('language', 0.5327599048614502),
#  ('lgpl', 0.5187968015670776),
#  ('other', 0.5120983123779297),
#  ('must', 0.5062717199325562)]

# %%
# 단어간의 유사도
model1.wv.similarity("gensim", "study")
# Out:
# -0.31715336

# %% [markdown]
# ## 모델 저장 및 로딩
#
# ### 모델 저장, 로딩
# - `model.save('저장파일 경로')`
#   - gensim 자체 포맷으로 저장된다.
# - `gensim.models.Word2Vec.load('저장파일 경로')`
#   - `model.save()`로 저장된 모델을 Loading한다.

# %%
import os
os.makedirs("saved_models", exist_ok=True)

model1.save("saved_models/w2v_model.model")

# %%
from gensim.models import Word2Vec

load_model = Word2Vec.load("saved_models/w2v_model.model")

# %%
load_model.wv.most_similar("gensim")
# Out:
# [('commercial', 0.7190989851951599),
#  ('embeddings', 0.7149730324745178),
#  ('platform', 0.670430600643158),
#  ('support', 0.6412696838378906),
#  ('using', 0.596753716468811),
#  ('is', 0.5443570613861084),
#  ('language', 0.5327599048614502),
#  ('lgpl', 0.5187968015670776),
#  ('other', 0.5120983123779297),
#  ('must', 0.5062717199325562)]

# %% [markdown]
# ### Word Embedding Vector만 저장 및 로드
# - `KeyedVectors` 를 이용해 저장한다.
#     - `model.wv.save_word2vec_format('저장경로', binary=True|False)`
#         - binary=True: binary 파일로 저장한다. 용량이 작은 대신 내용확인이 안된다.
#         - binary=False: csv(공백구분자) 형식 text로 저장한다. 내용을 확인할 수있지만 파일용량이 크다.
# - `KeyedVectors.load_word2vec_format("저장경로", binary=True|False)`
#     - 저장시 binary에 맞춰 읽는다.

# %%
model1.wv.save_word2vec_format("saved_models/keyedvector.bin", binary=True)
model1.wv.save_word2vec_format("saved_models/keyedvector.csv", binary=False)

# %%
from gensim.models import KeyedVectors

load_wv_bin = KeyedVectors.load_word2vec_format("saved_models/keyedvector.bin", binary=True)

# %%
load_wv_csv = KeyedVectors.load_word2vec_format("saved_models/keyedvector.csv", binary=False)

# %%
load_wv_bin.most_similar("gensim")\
,load_wv_csv.most_similar("gensim")
# Out:
# ([('commercial', 0.7190989851951599),
#   ('embeddings', 0.7149730324745178),
#   ('platform', 0.670430600643158),
#   ('support', 0.6412696838378906),
#   ('using', 0.596753716468811),
#   ('is', 0.5443570613861084),
#   ('language', 0.5327599048614502),
#   ('lgpl', 0.5187968015670776),
#   ('other', 0.5120983123779297),
#   ('must', 0.5062717199325562)],
#  [('commercial', 0.7190989851951599),
#   ('embeddings', 0.7149730324745178),
#   ('platform', 0.670430600643158),
#   ('support', 0.6412696838378906),
#   ('using', 0.596753716468811),
#   ('is', 0.5443570613861084),
#   ('language', 0.5327599048614502),
#   ('lgpl', 0.5187968015670776),
#   ('other', 0.5120983123779297),
#   ('must', 0.5062717199325562)])

# %% [markdown]
# ## Pretrained 모델 사용하기
# - https://github.com/Kyubyong/wordvectors

# %%
from zipfile import ZipFile
with ZipFile("ko_new.zip") as zf:	# 압축풀 파일경로
	zf.extractall("saved_models")

# %%
ko_wv = KeyedVectors.load_word2vec_format(
	"saved_models/ko_new.txt",
	binary=False,
	encoding="utf-8"
)

# %%
word = "저녁"
ko_wv.most_similar(word, topn=5)
# Out:
# [('아침', 0.8432561755180359),
#  ('밤', 0.7863156199455261),
#  ('새벽', 0.7520349025726318),
#  ('점심', 0.7118877172470093),
#  ('그날', 0.7105917930603027)]

# %%
word = "고양이"
ko_wv.most_similar(word, topn=5)
# Out:
# [('토끼', 0.7924245595932007),
#  ('원숭이', 0.7570016384124756),
#  ('강아지', 0.7290453314781189),
#  ('돼지', 0.7203201651573181),
#  ('개구리', 0.7201221585273743)]

# %%
ko_wv[word]
# Out:
# array([ 2.58721089e+00, -1.19083822e+00,  1.02693021e-01,  1.05791342e+00,
#        -1.73088193e+00, -4.92587328e-01,  8.28979313e-02,  1.45242226e+00,
#         4.42151427e-01,  1.04589748e+00,  1.58645189e+00, -2.61376482e-02,
#         7.69314170e-01, -6.12096429e-01,  6.56534851e-01, -2.26123586e-01,
#         1.21184312e-01,  5.99661052e-01,  2.25671366e-01, -4.77610305e-02,
#         2.63381600e-01, -6.49069011e-01,  1.18908465e+00,  4.88096587e-02,
#        -1.52377498e+00, -1.48020709e+00,  3.10603404e+00,  1.54245174e+00,
#        -8.71144652e-01, -2.23441815e+00,  1.07638526e+00,  4.66621995e-01,
#         7.28348494e-01,  5.73255599e-01,  9.95010138e-01, -3.12950701e-01,
#        -6.26514375e-01,  2.04808339e-01, -6.00185513e-01,  3.69779378e-01,
#        -9.71896052e-01,  9.54610109e-01, -8.31314862e-01, -2.02365565e+00,
#        -2.81403124e-01, -1.29902530e+00, -7.05994308e-01, -1.24507181e-01,
#        -7.72656918e-01, -4.92854789e-02,  6.53591275e-01,  7.93715358e-01,
#        -2.32166261e-03,  4.14393306e-01, -2.05512714e+00, -3.37383002e-01,
#        -9.77245152e-01,  1.17383800e-01,  2.78027594e-01,  8.36566091e-01,
#         2.04441145e-01,  6.39230967e-01, -2.39022493e-01, -1.19986892e+00,
#         4.77629751e-01,  2.99206316e-01,  2.29924679e-01,  1.50265515e-01,
#         7.37724423e-01,  8.39603961e-01,  1.04578006e+00, -6.14199340e-01,
#        -1.20943710e-01,  4.92690593e-01,  1.51734293e+00, -1.15687335e+00,
#        -4.92789060e-01,  1.06846654e+00, -8.46203625e-01, -8.58228922e-01,
#         1.14440501e+00, -7.88520277e-01,  1.32777596e+00, -1.21479726e+00,
#        -2.14364719e+00, -6.49530768e-01, -3.14929456e-01, -5.31512022e-01,
#        -1.05130601e+00,  1.43782234e+00,  1.69859678e-02, -1.39322937e+00,
#        -8.79572332e-01, -1.12631094e+00,  7.72234797e-01,  9.42741394e-01,
#         9.18343544e-01,  6.29079044e-01,  1.25413644e+00,  2.77361423e-01,
#        -6.15891933e-01,  5.06046176e-01,  9.86464620e-01, -8.84694099e-01,
#        -2.48845369e-01, -1.65654689e-01, -1.84368208e-01, -7.10237801e-01,
#         7.00731426e-02, -3.04706618e-02,  2.40326381e+00,  4.80528921e-01,
#        -4.74073552e-02, -1.21438169e+00, -9.65048492e-01, -1.67920128e-01,
#         8.29936564e-01, -1.14859545e+00,  5.64489424e-01,  5.90726078e-01,
#         7.50666440e-01,  2.32355848e-01, -1.07395399e+00, -2.34621096e+00,
#         7.84997702e-01,  8.13206017e-01, -1.52594781e+00, -1.19561696e+00,
#         3.85164738e-01,  6.12635672e-01,  6.13197625e-01,  4.50155139e-01,
#         4.51780200e-01,  2.40641570e+00,  2.64069724e+00, -2.65938252e-01,
#         2.64825046e-01, -1.02699971e+00,  5.31768128e-02, -1.37471306e+00,
#         4.93015856e-01, -8.66602838e-01,  4.54439461e-01, -8.63911510e-01,
#         2.08070087e+00, -2.36849591e-01,  5.39233088e-01, -7.11860597e-01,
#        -8.94051850e-01, -7.05624640e-01, -5.66361070e-01,  7.50745535e-01,
#         1.13472354e-03, -2.59964075e-02,  7.15921164e-01, -8.76369178e-01,
#         3.35227251e-01,  1.13361204e+00, -7.52132118e-01, -4.75091279e-01,
#        -5.66046834e-01, -1.81995046e+00, -3.08129221e-01, -2.79548383e+00,
#        -1.14942968e+00, -1.84629083e+00,  1.17562652e+00,  1.05138734e-01,
#        -1.71807909e+00,  3.69065136e-01, -1.83372605e+00,  2.58956850e-01,
#         4.39346321e-02,  1.13649035e+00, -1.19913602e+00, -7.40754485e-01,
#         3.41195911e-01, -3.54268551e-01, -1.02949776e-01, -1.88555062e-01,
#        -1.08293128e+00, -3.50589752e-01,  1.88072145e+00,  1.11933839e+00,
#         5.86183667e-01,  1.47418547e+00, -7.68811628e-02,  1.41522735e-01,
#         4.21723798e-02,  1.79532409e+00,  6.37477636e-01,  1.01902139e+00,
#        -1.44701088e-02, -1.14796722e+00, -1.09180510e-01,  1.34468526e-01,
#         5.38899720e-01,  1.96584716e-01,  2.44551197e-01, -1.80794001e+00],
#       dtype=float32)

# %% [markdown]
# # 빅카인즈 뉴스 데이터를 이용한 Word2Vec 학습
# - 빅카인즈
#     - 한국언론진흥재단에서 운영하는 뉴스빅데이터 분석 서비스 사이트
# - 빅카인즈에서 특정 분야의 기사들을 수집해서 학습시킨다.
#     - https://www.bigkinds.or.kr/
#     - 회원가입 (구글, 네이버, 카카오 계정으로 가입 가능) 후 로그인
#     - 뉴스분석 > 뉴스검색$\cdot$분석 클릭
#     ![word2vec_bigkinds1.png](figures/word2vec_bigkinds1.png)
#     - 기간, 언론사, 분류, 상세검색 등 검색 조건입력 후 조회
#     ![word2vec_bigkinds1.png](figures/word2vec_bigkinds2.png)
#     - 결과 다운로드
#         - step3 분석결과및 시각화 -> 맨 아래 `엑셀다운로드` 클릭
#     ![word2vec_bigkinds1.png](figures/word2vec_bigkinds3.png)

# %%
# %pip install openpyxl
# Out:
# Collecting openpyxl
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Using cached et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Using cached openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Using cached et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    ---------------------------------------- 2/2 [openpyxl]
#
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

df = pd.read_excel("NewsResult_20250223-20250523.xlsx")
# Out:
# c:\Users\Playdata\miniconda3\envs\dl\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
df.shape
# Out:
# (2303, 19)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2303 entries, 0 to 2302
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   뉴스 식별자             2303 non-null   float64
#  1   일자                 2303 non-null   int64
#  2   언론사                2303 non-null   object
#  3   기고자                1910 non-null   object
#  4   제목                 2303 non-null   object
#  5   통합 분류1             2303 non-null   object
#  6   통합 분류2             1933 non-null   object
#  7   통합 분류3             1664 non-null   object
#  8   사건/사고 분류1          2303 non-null   object
#  9   사건/사고 분류2          938 non-null    object
#  10  사건/사고 분류3          307 non-null    object
#  11  인물                 1390 non-null   object
#  12  위치                 2254 non-null   object
#  13  기관                 2247 non-null   object
#  14  키워드                2303 non-null   object
#  15  특성추출(가중치순 상위 50개)  2303 non-null   object
#  16  본문                 2303 non-null   object
#  17  URL                2256 non-null   object
#  18  분석제외 여부            60 non-null     object
# dtypes: float64(1), int64(1), object(17)
# memory usage: 342.0+ KB

# %%
df.head(2)
# Out:
#          뉴스 식별자        일자   언론사     기고자  \
# 0  1.101001e+06  20250523   한겨레  김남일 기자
# 1  1.100701e+06  20250523  세계일보     김정모
#
#                                       제목    통합 분류1     통합 분류2  통합 분류3  \
# 0  검사 판사가 유권자 결정 바꾸는 선거법 ‘삭제→부활→삭제’ 30년사  정치>국회_정당   사회>사건_사고   정치>선거
# 1    환경장관 만난 김태흠 충남지사 “청양 부여 지천댐 조속 건설을”   사회>사회일반      지역>강원   지역>충남
#
#       사건/사고 분류1    사건/사고 분류2 사건/사고 분류3                                 인물  \
# 0  범죄>기업범죄>거래제한   재해>자연재해>홍수       NaN  김,3천만원,김문수,김지영,김용빈,유상범,이재명,마타,신중한
# 1    재해>자연재해>가뭄   재해>자연재해>홍수       NaN                            김완섭,김태흠
#
#                                                   위치  \
# 0                                  영국,공직선거 및 선거부정방지법
# 1  정부세종청사,은산면,수원,부여군,태평양,아시아,청양군,장평면,용수,보령댐,대청댐,부...
#
#                                                   기관  \
# 0  캐나다,대검찰청,민주당,국회 법사위,헌법연구관,검찰,국회 법제사법위,경찰,더불어민주...
# 1                 환경부,정부,부여군,환경부장관,충남지사,충남,보령댐,용수,청양
#
#                                                  키워드  \
# 0  검사,판사,유권자,결정,선거법,삭제,부활,삭제,30년,혐의,공직선거법,위반,재판,이...
# 1  환경장관,청양,김태흠,충남,지사,부여,건설,지천댐,조속,김태흠,충남,지사,청양,부여...
#
#                                    특성추출(가중치순 상위 50개)  \
# 0  후보자,공직선거법,허위사실공표죄,선거법,이재명,허위사실공표,대법원,유권자,위원회,통...
# 1  지천댐,청양,충남,부여,보령댐,후보지,부여군,대청댐,수원,김태흠,환경부,아시아,김완...
#
#                                                   본문  \
# 0  공직선거법 위반 혐의로 재판을 받는 이재명 더불어민주당 대통령 후보는 대법원 전원합...
# 1  김태흠 충남지사가 청양 부여 지천댐 건설을 조속하게 추진해 줄 것을 정부에 요청했다...
#
#                                                  URL 분석제외 여부
# 0  http://www.hani.co.kr/arti/politics/election/1...     NaN
# 1  http://www.segye.com/content/html/2025/05/22/2...     NaN

# %%
df = df[["제목", "본문"]]
df.head(2)
# Out:
#                                       제목  \
# 0  검사 판사가 유권자 결정 바꾸는 선거법 ‘삭제→부활→삭제’ 30년사
# 1    환경장관 만난 김태흠 충남지사 “청양 부여 지천댐 조속 건설을”
#
#                                                   본문
# 0  공직선거법 위반 혐의로 재판을 받는 이재명 더불어민주당 대통령 후보는 대법원 전원합...
# 1  김태흠 충남지사가 청양 부여 지천댐 건설을 조속하게 추진해 줄 것을 정부에 요청했다...

# %% [markdown]
# ### TODO

# %%
# 문서 : 개별 뉴스 기사(제목 + 본문)
tokens_title = tokenizer(df["제목"])
tokens_body = tokenizer(df["본문"])
tokens_title, tokens_body
# Out:
# ([['검사', '판사가', '유권자', '결정', '바꾸는', '선거법', '삭제', '부활', '삭제', '30년사'],
#   ['환경장관', '만난', '김태흠', '충남지사', '청양', '부여', '지천댐', '조속', '건설을'],
#   ['유석재의', '돌발史전', '나는', '이제', '더', '이상', '마오', '를', '존경하지', '않는다'],
#   ['이', '정책만은', '정권', '초월해야', '부처별', '지속', '과제', '지키기', '안간힘'],
#   ['안전사고', '대국', '中', '잇따라', '인명', '사고', '발생'],
#   ['음식의', '미래', '5월', '만감이', '달콤하지만은', '않은', '까닭'],
#   ['eu', '중국과', '협력하되', '이익이', '먼저', '중국산', '타이어', '반덤핑', '조사', '나섰다'],
#   ['경북', '산불', '이재민', '임시주택', '설치', '하세월'],
#   ['中', '구이저우', '산사태로', '21명', '매몰', '기후변화로', '폭염', '폭우', '심화'],
#   ['김태흠', '지사', '청양', '부여', '지천댐', '신속', '추진', '정부에', '요청'],
#   ['쉽게', '중국', '편', '안', '되네', 'eu', '중국산', '승용차', '타이어에', '반덤핑', '조사', '개시'],
#   ['미야자키', '하야오가', '어떻게', '살', '것인가', '묻는', '까닭', '이', '다큐', '보면', '나온다'],
#   ['코리아스페이스', '수원', '매향여자정보고', '조리실에', '설치된', '청정공기', '급기설비', '성능시험', '실시'],
#   ['관악구', '풍수해', '대책', '업그레이드', '구민', '안전', '최우선'],
#   ['온열질환', '제로', '현대건설', '혹서기', '현장', '근로자', '온열질환', '예방', '캠페인', '실기'],
#   ['경북', '산불', '두달', '아직도', '임시텐트에', '사는', '이재민들', '산사태', '우려까지'],
#   ['코리아스페이스',
#    '수원',
#    '매향여자정보고',
#    '조리실',
#    '내',
#    '설치된',
#    '청정공기',
#    '급기설비',
#    '성능',
#    '테스트',
#    '진행'],
#   ['장수군의회', '제375회', '임시회', '개회', '조례', '등', '9건', '심의', '의결'],
#   ['전북도', '2024년', '온실가스', '273만t', '감축', '목표', '106', '초과', '달성'],
#   ['대한항공', '아시아나', '몽골서', '나무심기'],
#   ['때이른', '무더위에', '예비', '전력', '마지노선', '10gw', '무너져'],
#   ['폭염', '대응', '나선', '현대건설', '힐스테이트', '메디알레', '서', '안전관리', '강화'],
#   ['북미대륙', '지각판이', '얇아지고', '있다', '지형도', '바뀌나'],
#   ['폭우', '오기', '전', '미리미리', '농어촌공사', '경기본부', '재난', '재해', '대응태세', '확립'],
#   ['침수',
#    '우려',
#    '1450여',
#    '가구',
#    '물막이판설치',
#    '빗물받이',
#    'qr코드',
#    '식별부호',
#    '부여',
#    '관악구',
#    '풍수해',
#    '대책본부',
#    '본격',
#    '가동'],
#   ['바다도', '덥다', '하와이', '스노클링에서', '마주한', '충격', '장면'],
#   ['오늘의', '날씨', '오전', '2025년', '05월', '22일'],
#   ['섬부터', '산골까지', '기후', '재난', '대비', '전기설비', '점검'],
#   ['사설', '대선', '국면', '검사', '줄사퇴', '정치와', '얽힌', '검찰의', '씁쓸한', '풍경'],
#   ['물막이판',
#    '빗물받이에',
#    'qr코드',
#    '부착',
#    '물샐틈없는',
#    '관악구',
#    '수해',
#    '예방',
#    '대책',
#    '현장',
#    '행정'],
#   ['용산', '23일', '주민과', '함께하는', '안전한국훈련'],
#   ['까맣게', '타버린', '야생동물', '보금자리', '이', '아픔', '개발', '호재로', '삼아선', '안', '돼'],
#   ['기고', '좌절에서', '희망으로', '새만금', '신구상'],
#   ['포항지진', '항소심', '패소에', '시민단체', '집단반발', '이어져', '피해', '구제해야'],
#   ['alc',
#    '2025',
#    '日',
#    '건축',
#    '거장',
#    '반',
#    '시게루',
#    '권력자',
#    '부자만을',
#    '위해',
#    '일하지',
#    '않는다'],
#   ['무공수훈자회',
#    '경북',
#    '산불피해',
#    '국가유공자',
#    '회원',
#    '돕기',
#    '3371명이',
#    '모은',
#    '성금',
#    '1억3천여만원',
#    '전달'],
#   ['고수온에', '강원', '원정양식까지', '멍게', '최대산지', '경남', '올핸', '지각', '출하'],
#   ['김동영', '경기도의원', '장마철', '앞두고', '철저한', '국지도', '지방도', '점검', '당부'],
#   ['⑤',
#    '10만원',
#    '더',
#    '남기려다',
#    '사람',
#    '잡는',
#    '세상',
#    '한순간',
#    '사그라진',
#    '아들의',
#    '생애',
#    '앞에서',
#    '생사고투'],
#   ['전남도', '산사태', '취약지', '145곳', '신규', '지정', '주민', '1만여명', '대피체계', '구축'],
#   ['동물학자',
#    '우동걸',
#    '산불로',
#    '터전',
#    '잃은',
#    '야생동물',
#    '동물의',
#    '아픔',
#    '개발',
#    '호재로',
#    '삼지',
#    '말아야',
#    '인터뷰'],
#   ['몽골', '대한항공', '숲', '에서', '대한항공', '아시아나항공', '임직원', '식림', '활동', '한강로', '사진관'],
#   ['경북', '포항지진', '뒤집힌', '판결에', '진통', '지속', '정부', '항의', '방문까지'],
#   ['대한항공', '21년', '이어온', '몽골', '식림', '아시아나와', '함께', '심는다'],
#   ['수공', '2025년', '재난대응', '안전한국훈련'],
#   ['전남도', '재난', '대비', '산사태', '상황실', '운영'],
#   ['신림차고지', '빗물저류조', '가동'],
#   ['용산구', '2025년', '재난대응', '안전한국훈련', '실시'],
#   ['전남도', '여름철', '산사태', '선제', '대응', '나서'],
#   ['전남도', '벼', '농작물', '재해보험료', '90', '지원'],
#   ['전남도', '안전한', '영농', '위한', '벼', '농작물', '재해보험료', '90', '지원'],
#   ['전남도', '여름철', '집중호우', '산사태', '대비', '총력', '대책상황실', '운영'],
#   ['전남도', '태풍', '호우', '병해충', '등', '벼', '농작물', '재해보험료', '90', '지원'],
#   ['간판', '하나로', '주민', '만족', '쑥', '영등포구', '안전과', '도시미관', '다', '잡았다'],
#   ['전남도', '여름철', '집중호우', '대비', '산사태', '대책상황실', '운영'],
#   ['봄바람에', '웃다', '콧물에', '울다', '환절기', '당신의', '코', '상태는'],
#   ['단독', '탈원전', '뒤집기에도', '꿋꿋', '대만', '원전', '없는', '나라', '완성하다'],
#   ['끝까지', '원전으로', '정쟁', '하는', '대만', '국민당'],
#   ['전남', '마을', '안전지킴이로', '기후재난', '대응'],
#   ['오늘의', '날씨', '오전', '2025년', '05월', '21일'],
#   ['도로공사만', '10년째', '하고있다', '강서', '양천구', '주민들', '분통', '왜'],
#   ['日', '열사병', '사망', '절반', '전기료', '아끼려', '에어컨', '안켜'],
#   ['쇳가루', '날리던', '인천', '사월마을', '친환경', '도시로', '재정비'],
#   ['ceo', 'cfo보다', '빛나는', '명장', '타이틀', '고졸들이', '꿰찼다'],
#   ['전남도', '이상기후', '대응', '마을', '안전지킴이', '운영'],
#   ['너섬情談', '여름이', '무섭다'],
#   ['포항시', '포항지진', '항소심', '판결', '관련', '향후', '대응계획', '발표'],
#   ['훈련도', '실전처럼', '재난대응', '안전한국훈련'],
#   ['고기동',
#    '행안장관',
#    '직무대행',
#    '예산보다',
#    '더',
#    '중요한',
#    '건',
#    '관심',
#    '지방소멸',
#    '재난',
#    '대응',
#    '총력',
#    '세계초대석'],
#   ['지진이', '발생한다면', '수공', '재난대응', '안전한국훈련', '실시'],
#   ['월드비전', '아동권리대표단', '기후', '취약계층을', '위한', '7대', '정책', '제안'],
#   ['포항지진', '손해배상', '상고심', '모든', '조치', '취할', '것', '포항시', '대응계획', '발표'],
#   ['보훈부', '재난안전체험교육', '본부', '직원', '100여명', '참가'],
#   ['오늘의', '인천', '남동구', '폐현수막', '친환경', '고형연료로', '재활용'],
#   ['농어촌공사', '함평지사', '저수지', '붕괴', '가상', '비상대처', '훈련', '실시'],
#   ['폭염', '피해', '막아라', '양천구', '종합대책', '본격추진'],
#   ['경북', '포항시', '지진', '피해', '손해배상', '상고', '앞두고', '본격', '대응', '추진'],
#   ['강동구', '2025', '재난대응', '안전한국훈련', '한강로', '사진관'],
#   ['금호', '화재', '광주', '유해물질', '기준치', '이하', '시민은', '숨쉬기', '힘들어'],
#   ['어르신', '더우시죠', '가평군', '폭염', '대비', '건강취약계층', '방문', '점검'],
#   ['이번엔', '정읍시', '반복되는', '고형폐기물', '연료', '소각', '발전', '시설', '갈등'],
#   ['산불', '막는', '데', '필요하다는', '임도', '감사원', '부실', '시공으로', '산사태', '유발'],
#   ['머스크의', 'xai', '데이터센터', '공해', '논란', '주민들', '숨막힌다', '반발'],
#   ['코트라', '中', '액티브', '시니어', '공략', '베이징서', '헬스케어', '로드쇼'],
#   ['전남도', '이상기후', '대응', '마을', '안전지킴이', '운영'],
#   ['전남도', '집중호우', '산사태', '등', '이상기후', '대응', '마을', '안전지킴이', '첫', '운영'],
#   ['인천', '사월마을', '친환경', '도시로', '탈바꿈하는', '도시개발', '마스터플랜', '발표'],
#   ['은평구', '9월까지', '폭염대책', '추진'],
#   ['송파구', '폭염', '집중호우', '선제', '대응'],
#   ['양천구', '재난', '도우미', '1053명', '운영', '폭염', '대비', '총력전', '펼친다'],
#   ['오늘의', '날씨', '오전', '2025년', '05월', '20일'],
#   ['침묵은', '위험하다', '수다', '떨지', '않으면', '어떻게', '소통할', '것인가'],
#   ['이명현의',
#    '별과',
#    '우주',
#    '태양',
#    '흑점',
#    '극대기',
#    '올해와',
#    '내년',
#    '오로라',
#    '관측할',
#    '최상의',
#    '기회'],
#   ['오늘과', '내일', '박용', '청년은', '기회', '노년은', '소득이', '없는', '나라'],
#   ['광주', '타이어', '화재', '현장', '찾은', '이준석', '대선', '후보', '중', '처음'],
#   ['팩트', '다이브', '원전', '히로시마급', '핵폭탄', '떨어져도', '안전하다고'],
#   ['맨홀부터', '대관람차까지', '원이', '숨', '쉬는', '우리', '일상'],
#   ['훈련', '점검', '설치', '3박자로', '광진구는', '풍수해', '무풍지대'],
#   ['경북', '김천서', '규모', '2', '4', '지진', '최대', '진도ⅲ', '흔들림', '감지'],
#   ['강동구', '우기철', '산사태', '대비해', '대규모', '안전한국훈련', '실시'],
#   ['경북', '김천', '북동쪽서', '규모', '2', '4', '지진', '큰', '피해', '없을', '듯'],
#   ['경남소방본부', '여름철', '대비', '119폭염구급대', '본격', '운영'],
#   ['포항', '냉천교', '재가설', '현장서', '50대', '근로자', '매몰돼', '숨져'],
#   ['경북', '김천', '동북동쪽서', '규모', '2', '4', '지진', '인근엔', '흔들림'],
#   ['경북', '김천서', '규모', '2', '4', '지진', '차량', '흔들려'],
#   ['주말새', '전국서', '대선벽보', '훼손', '빈발'],
#   ['화성에', '물', '있다는', '증거', '알고', '보니', '착각', '달콤한', '사이언스'],
#   ['금천구', '여름철', '종합대책', '본격', '가동', '폭염', '호우', '등', '전방위', '대응'],
#   ['포토타임', '지진피해', '입은', '극장', '가정한', '재난대응', '안전한국훈련'],
#   ['오늘', '커피가', '가장', '저렴한', '날입니다'],
#   ['경기도', '임진강', '집중호우', '및', '무단방류', '대비', '주민대피훈련', '실시'],
#   ['걸리면', '손', '쓸', '방법', '없어', '과수화상병', '확산', '초비상'],
#   ['오늘의', '날씨', '오전', '2025년', '05월', '19일'],
#   ['풍수해', '인명피해', '막는', '사전대피와', '통제', '기고'],
#   ['경기도', '9월까지', '폭염', '종합대책', '기후보험으로', '온열질환도', '보상'],
#   ['dbr', '히타치', '디지털', '전환으로', '위기', '극복하며', '부활', '성공'],
#   ['궂은', '일', '싫다면서', '급식', '로봇엔', '반대하는', '조리사들'],
#   ['여름철',
#    '태풍',
#    '집중호우도',
#    '유비무환',
#    '실전',
#    '훈련',
#    '통해',
#    '재해',
#    '대비하는',
#    '용산',
#    '현장',
#    '행정'],
#   ['7월', '진짜', '대재난', '온다', '만화發', '괴담', '덮친', '日'],
#   ['포항지진', '대시민', '안내센터', '본격', '가동', '시민', '혼란', '및', '불편', '최소화', '나서'],
#   ['핵실험', '감시병', '에', '주어진', '새', '임무', '조용히', '다가오는', '우주', '재앙', '을', '막아라'],
#   ['정동칼럼', '여름이', '오고', '있다'],
#   ['물폭탄', '대비했나요', '국토부', '두', '달간', '건설현장', '우기점검'],
#   ['분진', '냄새로', '고통', '금호타이어', '화재에', '주민들', '통증', '호소'],
#   ['외계인에',
#    '들려주는',
#    '지구인의',
#    '세계사',
#    '한',
#    '옛날',
#    '인더스',
#    '지역의',
#    '세계',
#    '무역',
#    '문명의',
#    '새벽을',
#    '연',
#    '바닷길'],
#   ['기후변화에', '바지락', '생산량', '75', '감소', '경기도', '폭염대책', '앞당긴다'],
#   ['이천시', '국가재난관리', '탁월', '입증', '행안부', '유공', '3관왕', '수상'],
#   ['포항지진', '대시민', '안내센터', '운영', '시민', '혼란', '불편', '최소화'],
#   ['문경시', '시의회', '청사', '신축사업', '본격화', '구', '도심지역의', '새로운', '랜드마크', '기대'],
#   ['핵실험', '감시', '장비로', '우주', '재앙', '피한다니', '어떻게'],
#   ['서울여대', '미얀마', '지진', '피해', '유학생에', '장학금', '지원'],
#   ['인도네시아의', '숨겨진', '보석', '빈탄의', '밀림', '속으로', '전승훈', '기자의', '아트로드'],
#   ['환자', '대소변', '받는', '조선족', '간병인', '50년', '전', '파독', '간호사', '닮았다'],
#   ['온전한', '피해자서', '수동적', '가해자', '된', '차별', '이득', '사회', '오늘', '한국인'],
#   ['오늘의', '날씨', '오전', '2025년', '05월', '17일'],
#   ['크리스탈', '라군과', '맹그로브', '숲', '빈탄의', '아침을', '달리다', '전승훈', '기자의', '아트로드'],
#   ['5월', '우리', '지역에서', '열리는', '행사와', '강좌'],
#   ['시간당', '70mm', '물폭탄에', '차량', '고립도', '17일', '새벽쯤', '비', '그칠', '듯'],
#   ['내일', '새벽까지', '많은', '비', '전남', '경남', '제주', '산사태', '위기경보', '주의', '로', '상향'],
#   ['경북', '포항시', '지진', '피해', '소송', '대시민', '안내센터', '운영'],
#   ['인명피해', '없도록', '철저', '대비', '춘천시', '여름철', '재난', '대응체계', '점검'],
#   ['폭우', '드루와', '중랑구', '풍수해', '종합대책', '마련'],
#   ['성동구',
#    '우기',
#    '대비',
#    '건축공사장',
#    '등',
#    '180개소',
#    '안전점검',
#    '24시간',
#    '풍수해',
#    '대비도',
#    '철저'],
#   ['구로구', '2025년', '풍수해', '대비', '현장훈련', '교육으로', '안전망', '강화한다'],
#   ['백섬백길', '걷기여행', '222', '차귀도', '둘레길', '천연기념물이', '된', '제주의', '무인도'],
#   ['310', '폭우', '가상상황', '만들어', '방류', '훈련', '올', '장마', '완벽대비'],
#   ['서울여자대학교', '미얀마', '지진', '피해', '유학생에', '긴급', '구호', '장학금', '지원'],
#   ['홍콩인들', '일본', '여행', '취소', '잇따라', '7월', '대재앙', '예언', '때문'],
#   ['구민', '안전', '최우선', '서울', '중구', '여름철', '안전', '사고', '종합대책', '마련'],
#   ['7월',
#    '일본에',
#    '대재앙',
#    '온다',
#    '예언에',
#    '여행',
#    '취소',
#    '줄줄',
#    '코로나',
#    '예언도',
#    '적중했다',
#    '핫이슈'],
#   ['재난', '대응', '현장', '훈련', '나선', '구로구', '차수판', '설치', '훈련도'],
#   ['포항시민단체', '국가', '면책판결은', '사법부', '횡포'],
#   ['서울', '중구', '여름철', '자연재난', '안전사고', '종합대책', '마련'],
#   ['환경', '균형의', '시대①', '2040년대', '마이너스', '성장', '경고', '댐', '건설', '절실'],
#   ['센트럴파크에', '수영장', '아이스링크가', '2200억원', '들여', '대변신'],
#   ['울산시', '태풍', '호우', '피해에', '최대', '2000만', '원', '보상'],
#   ['극한', '홍수', '막자', '수자원공사', '실전형', '대응체계', '가동'],
#   ['호우', '긴급재난문자', '전국으로', '확대'],
#   ['코로나', '거치면서', '대중의', '과학화', '이뤄진', '걸', '보고', '기뻤죠'],
#   ['담뱃불로',
#    '지지고',
#    '찢고',
#    '전국',
#    '곳곳',
#    '선거',
#    '현수막',
#    '테러',
#    '처벌',
#    '수위는',
#    '미드나잇',
#    '이슈'],
#   ['포항지발협', '포항촉발지진', '국가', '배상', '책임', '없다', '는', '법원', '판결', '강한', '유감'],
#   ['녹색세상', '정치가', '미래를', '버릴지도'],
#   ['모르면', '나만', '손해', '암의', '씨앗', '만성염증', '뿌리', '뽑는', '신의', '선물'],
#   ['충주댐서', '홍수', '모의훈련', '물그릇', '68억t', '확보'],
#   ['경북', '산불도', '산업화가', '낳은', '재앙', '해결책은', '녹색성장'],
#   ['두달뒤', '대재난', '발생', '예언', '맞을까', '예언가가', '최근', '전한', '말'],
#   ['머스크의', 'ai', '챗봇', '관련', '없는', '질문에', '남아공', '백인학살', '답변', '신뢰성', '우려'],
#   ['경북', '포항시', '힌남노', '피해', '입은', '농촌지역', '정주', '여건', '개선', '343억원', '투입'],
#   ['호우', '긴급재난문자', '전국', '확대'],
#   ['7월에', '일본', '대재앙', '온다', '예언에', '홍콩서', '여행', '취소', '확산'],
#   ['전국', '곳곳서', '대선', '펼침막', '훼손', '최대', '징역', '2년이나', '벌금', '400만원'],
#   ['포항시', '힌남노', '피해', '농촌', '회복', '5년간', '343억원', '투입', '농식품부와', '협약'],
#   ['포항지진', '범대본', '항소심', '판결', '국민권익', '무시', '시민', '총궐기', '제안'],
#   ['지금', '양천은', '환경교육', '이젠', '의무', 'y교육박람회', '2025', '개막'],
#   ['강동구', '여름철', '풍수해', '대비', '재난안전대책본부', '본격', '가동'],
#   ['포항', '지진', '엇갈린', '판결에', '반발', '지속', '시민총궐기', '등', '동참해야'],
#   ['안동시', '제2회', '추가경정예산안', '3375억원', '규모', '편성'],
#   ['이강덕', '시장', '회색빛', '공업도시는', '잊어라', '포항은', '이미', '녹색도시'],
#   ['과학적', '상상이', '현실로', '화성', '하늘에', '펼쳐진', '오로라'],
#   ['한', '미얀마', '수교', '50주년', 'kf아세안문화원', '미얀마', '문화의', '날', '개최'],
#   ['환절기만', '여름에도', '찾아오는', '비염의', '이유는'],
#   ['부산시설공단', '태풍', '호우', '대비', '안전점검', '착수'],
#   ['산사태', '우려지역', '279곳', '우선복구'],
#   ['도시나무', '쓰러짐', '예측시스템', '개발'],
#   ['5일', '빨라진', '폭염', '잦은', '극한호우', '비상'],
#   ['기상청', '호우', '긴급재난문자', '전국', '읍면동까지', '신속히', '발송'],
#   ['아주대', '미얀마', '지진피해', '복구', '성금', '1083만', '원', '전달'],
#   ['태안군', '폭염상황', '관리', '합동', 't', 'f팀', '운영'],
#   ['도깨비', '폭우', '20분전', '긴급문자만', '받았다면', '오늘부터', '전국', '발송'],
#   ['생명', '살리는', '호우', '재난문자', '오늘부터', '전국', '확대'],
#   ['동부지방산림청', '산사태', '대책상황실', '본격', '가동'],
#   ['대구시민건강놀이터', '오는', '9월까지', '폭염', '대비', '프로그램', '운영'],
#   ['화성', '땅에서도', '오로라', '보인다', 'nasa', '퍼서비어런스', '사상', '첫', '포착', '우주를', '보다'],
#   ['대구시', '20일부터', '시민의', '온열질환', '피해', '예방을', '위한', '선제', '대응'],
#   ['서울시', '취약계층', '폭염', '폭우', '대비', '풀가동'],
#   ['더버터', '일상에서', '피어난', '선한', '영향력', '평범한', '이웃들의', '특별한', '기부'],
#   ['더버터', '기아종식의', '가장', '큰', '걸림돌은', '편견', '입니다'],
#   ['더버터', '한국의', '기부자를', '소개합니다', '더기버스50', '1차', '명단', '공개'],
#   ['경기', '이상기후', '대응', '비상대비', '근무', '단계', '추가'],
#   ['경기도', '재난', '안전', '비상대비', '단계', '신설'],
#   ['대형', '산불', '피해지', '집중', '관리', '산림청', '산사태', '방지대책', '발표'],
#   ['호우', '긴급재난문자', '전국', '확대'],
#   ['영남', '산불피해지역', '279곳', '산사태', '위험'],
#   ['이른', '더위에', '온열질환', '관리', '15일부터', '돌입'],
#   ['포항지진', '항소심', '패소에', '포항시민', '집단', '반발', '다음주', '대법원', '상고'],
#   ['새', '정부는', '안전', '없는', '에너지', '전략', '폐기해야', '왜냐면'],
#   ['이재명', '공약에', '탄소세', '빠졌는데', '국회', '예정처', '한국도', '유럽처럼', '탄소세', '고려', '권고'],
#   ['ai', '디지털', '트윈', '기술로', '홍수기', '대응', '위험', '신속', '전파'],
#   ['한',
#    '치',
#    '앞도',
#    '안',
#    '보여',
#    '中',
#    '관광지',
#    '덮친',
#    '태풍급',
#    '모래폭풍',
#    '1만',
#    '명',
#    '고립'],
#   ['영상', '모래에', '1만', '명', '갇혔다', '종말', '같은', '中', '모래폭풍', '현장', '포착'],
#   ['부산시', '여름철', '자연재난', '대비', '점검회의', '및', '현장점검', '실시', '시민', '안전', '최우선'],
#   ['하남시', '재난', '행동요령', '책자', '다국어', '제작', '외국인도', '쉽게', '활용'],
#   ['하늘에서', '계란이', '쏟아진', '듯', '초대형', '우박의', '베이징', '습격'],
#   ['이철우',
#    '경북지사',
#    '대형',
#    '산불',
#    '피해지역',
#    '2차',
#    '피해',
#    '예방',
#    '시설',
#    '공사',
#    '조속',
#    '완료'],
#   ['행안부', '풍수해', '대비', '호우', '재난문자', '확대', '무더위', '쉼터', '6만여', '곳', '운영'],
#   ['서울시', '취약계층', '보호', '여름', '폭염', '폭우', '대책', '가동'],
#   ['정부', '댐', '비우고', 'ai', '활용해', '홍수', '대응', '강화'],
#   ['정부', '풍수해', '폭염', '대책', '가동', '영남권', '산불', '피해', '지역', '특별', '관리'],
#   ['군산의', '미래', '달렸다', '군산시', '2026년', '국가예산', '확보', '본격', '시동'],
#   ['김해시', '공무원', '102명', '시민안전', '책임진다', '재난기동대', '발족'],
#   ['클릭자치현장', '시민', '안전', '지키는', '김해', 'g1', '전국', '첫', '공무원', '재난기동대', '발족'],
#   ['영남', '초대형', '산불', '지역', '산사태', '위험', '급증'],
#   ['대형', '산불', '피해지', '집중', '관리한다', '산림청', '산사태', '방지대책', '발표'],
#   ['산불발생지역',
#    '2차',
#    '피해',
#    '막고',
#    '드론',
#    '활용',
#    '더위',
#    '사망자',
#    '막는다',
#    '정부',
#    '여름철',
#    '재난',
#    '대응',
#    '총력'],
#   ['마포구', '여름', '태풍', '대비', '옥외광고물', '점검'],
#   ['올', '여름', '평년', '기온', '웃돌아', '정부', '노인', '대피', '도우미', '지원키로'],
#   ['폭염', '대피용', '쉼터', '꾸리고', '어르신', '안부', '확인', '서울시', '여름철', '대책', '가동'],
#   ['일찍', '온', '더위', '온열질환', '감시체계', '5일', '앞당겨', '내일부터', '가동'],
#   ['지진피해', '포항시민', '국가면책', '판결', '에', '분노'],
#   ['겨울엔', '제설차', '여름에는', '살수차'],
#   ['최근',
#    '10년간',
#    '풍수해',
#    '사망',
#    '실종',
#    '174명',
#    '차량',
#    '이용',
#    '이동',
#    '주차',
#    '중',
#    '40명',
#    '숨져'],
#   ['올여름', '6월부터', '덥다', '질병청', '전년보다', '5일', '앞서', '온열질환', '감시', '시작'],
#   ['풍수해', '대비', '호우', '재난문자', '전국', '확대', '폭염', '시', '사업주', '보건조치', '의무화'],
#   ['6월', '부터', '무더위', '온다', '질병청', '온열질환', '감시체계', '조기', '가동'],
#   ['극한호우로', '순식간에', '범람하는', '한강', '가상세계서', '예측해', '막는다'],
#   ['폭염특보시', '취약계층', '안부', '확인', '서울시', '여름철', '종합대책', '추진'],
#   ['폭염', '수방', '안전', '보건', '서울시', '10월까지', '여름철', '종합대책', '실시'],
#   ['영남', '산불피해지', '279곳', '산사태', '우려', '높아', '산림당국', '응급복구', '등', '집중관리'],
#   ['경기도', '재대본', '비상대비', '단계', '신설한다'],
#   ['울산시', '시민안전보험', '지원사업', '추진', '최대', '2000만원', '보상'],
#   ['경기도', '재난안전대책본부에', '비상대비', '단계', '신설', '재난', '감시', '체계', '구축'],
#   ['tk는', '이번에', '어떤', '선택을', '할', '것인가', '5월14일', '뉴스뷰리핑'],
#   ['경기도', '재대본', '비상대비', '단계', '신설', '이상기후', '선제', '대응'],
#   ['정부', '지열발전사업', '과실로', '지진', '촉발', '입증', '안', '돼'],
#   ['설도권',
#    '클립서비스',
#    '대표',
#    '영화',
#    '매출',
#    '넘어선',
#    'k뮤지컬',
#    '흥행은',
#    '요행',
#    '아닌',
#    '철저한',
#    '설계',
#    '마이',
#    '라이프'],
#   ['오늘의', '날씨', '오전', '2025년', '05월', '14일'],
#   ['큰은혜교회', '18일', '창립', '70주년', '감사찬양제'],
#   ['포항지진', '1', '5조', '국가배상', '뒤집혀', '2심', '정부', '과실', '아니다'],
#   ['포항', '지진', '2심서', '뒤집혔다', '국가에', '피해', '배상', '책임', '없어'],
#   ['1인', '최대', '300만원', '0원', '포항지진', '판결', '2심서', '뒤집혔다'],
#   ['포항지진', '국가배상', '1500억', '2심', '0원'],
#   ['2심서', '뒤집힌', '포항지진', '관련기관', '과실로', '촉발', '입증안돼'],
#   ['과학산책', '우주기술', '우리', '삶의', '보이지', '않는', '궤도'],
#   ['포항', '지진', '국가배상책임', '0원', '국가', '과제', '영향', '있지만', '고의', '없어'],
#   ['포항시', '지진으로', '고통받은', '시민', '외면한', '판결'],
#   ['포항시민', '지진', '위자료', '국가', '상대', '손배소', '2심', '패소'],
#   ['1인당',
#    '300만',
#    '원',
#    '포항지진',
#    '위자료',
#    '2심서',
#    '없던',
#    '일로',
#    '시민',
#    '고통',
#    '외면',
#    '반발'],
#   ['포항지진', '국가', '배상', '책임', '없다', '1심', '뒤집혀'],
#   ['이철우', '정신적', '고통', '겪은', '시민들의', '현실', '반영하지', '못해', '유감'],
#   ['해운대구', '우동발전협의회', '마린시티', '앞', '재해방제용', '방파제', '연장', '촉구'],
#   ['항소심서', '뒤집힌', '포항지진', '손배소송', '국가', '배상', '책임', '없다'],
#   ['중남미', '바나나', '재배지', '2080년께', '60', '사라질', '수도'],
#   ['경북도', '산불', '피해', '도로', '42곳', '우기', '전', '복구', '160억', '투입'],
#   ['포항시', '지진', '인한', '시민', '고통', '반영', '못한', '판결', '개탄'],
#   ['이강덕', '포항시장', '촉발지진', '항소심', '판결', '유감', '대법원', '판단', '기대'],
#   ['용산구', '폭염엔', '쿨링포그', '호우엔', '배수로', '정비', '여름철', '종합대책', '본격', '가동'],
#   ['바나나', '기후', '위기', '직격탄', '세계', '최고', '인기', '과일', '죽여'],
#   ['미얀마', '군정', '수업', '중이던', '학교', '폭격', '학생', '포함', '최소', '22명', '사망'],
#   ['큰은혜교회', '창립', '70주년', '기념', '감사찬양제', '연다'],
#   ['포항지진', '손해배상', '소송', '항소심서', '뒤집혀', '이럴', '수', '있나', '포항시민', '반발'],
#   ['법원', '포항지진', '과실', '입증', '못해', '위자료', '불인정'],
#   ['포항지진', '뒤집힌', '1심', '판단', '촉발지진', '맞지만', '人災로', '보기', '어렵다'],
#   ['영상', '산불', '정보', '읽는', '자동기상망', '있지만', '대피', '때', '활용되지', '못', '했다'],
#   ['화창한', '날씨에', '난데없는', '30m', '먼지', '기둥', '英', '휩쓴', '회오리', '바람', '정체'],
#   ['포항지진', '민사소송', '항소심서', '뒤집혀', '과실', '부분', '입증', '부족'],
#   ['이주호', 'skt', '국민', '불편', '과기부', '재발방지대책', '내달라'],
#   ['폭염엔',
#    '쿨링포그',
#    '호우엔',
#    '배수로',
#    '정비',
#    '용산구',
#    '2025',
#    '여름철',
#    '종합대책',
#    '본격',
#    '가동'],
#   ['1', '5조원', '0원', '180도', '뒤집힌', '포항지진', '손배소', '판결', '왜'],
#   ['지구', '오로라보다', '밝고', '역동적', 'jwst가', '포착한', '목성', '오로라'],
#   ['포항지진', '민사소송', '항소심', '원고패소', '판결', '국가', '배상책임', '없어'],
#   ['포항지진', '국가', '과실', '입증', '부족', '위자료', '소송', '항소심서', '뒤집혀'],
#   ['법원', '포항', '지진', '국가', '배상책임', '없어', '뒤집힌', '2심에', '주민', '강력', '반발'],
#   ['무도한', '미얀마', '군부', '수업', '중이던', '학교', '폭격', '최소', '22명', '숨져'],
#   ['포항지진', '국가', '배상책임', '없다', '항소심서', '원고', '패소'],
#   ['포항지진', '국가', '배상책임', '없다', '항소심서', '1심', '뒤집혀'],
#   ['지구',
#    '오로라보다',
#    '수백',
#    '배',
#    '밝다',
#    '제임스웹',
#    '우주망원경',
#    '목성',
#    '오로라',
#    '포착',
#    '아하',
#    '우주'],
#   ['포항지진', '손배소송', '원심', '뒤집혀', '국가과실', '입증', '부족'],
#   ['속보', '뒤집힌', '포항', '지진', '위자료', '청구소송', '2심', '국가', '배상', '책임', '없다'],
#   ['전북도', '온열질환', '응급실', '감시체계', '9월30일까지', '가동'],
#   ['포항', '지진', '위자료', '1심', '200만', '300만원', '2심', '정부', '책임', '없다'],
#   ['속보',
#    '법원',
#    '포항지진',
#    '공무원',
#    '과실로',
#    '지진',
#    '났다',
#    '보기',
#    '어려워',
#    '정신적',
#    '위자료',
#    '항소심',
#    '기각'],
#   ['걱정', '없는', '여름', '일상', '영등포구', '여름철', '종합대책', '추진'],
#   ['속보', '포항지진', '위자료', '1인당', '300만원', '0원', '손배소', '2심', '원심', '뒤집었다'],
#   ['케이웨더', '폭염관리용', '체감온도', '측정기', '출시'],
#   ['포토타임', '낮에는', '더워요', '바닥', '분수에서', '물놀이하는', '어린이'],
#   ['강북구', '여름철', '안전사고', '예방', '위한', '종합대책', '시행'],
#   ['미얀마', '군부', '학교', '폭격해', '22명', '사망', '저항세력', '은신', '주장'],
#   ['간호사', '2명이', '830명', '전담', '사각지대', '내몰린', '쪽방촌', '돌봄'],
#   ['상처에도', '마음에도', '새살이', '돋기를', '경북', '산불에', '살아남은', '동물들'],
#   ['카드뉴스', '비염의', '계절', '고통', '받고', '있을', '비염인', '들을', '위한', '비염', '관리', '팁'],
#   ['오늘의', '날씨', '오전', '2025년', '05월', '13일'],
#   ['쓰레기산', '뒤지며', '사는', '아이들에게', '희망을', '학교', '세워', '교육사역'],
#   ['굿피플', '미얀마', '지진', '피해', '지역서', '긴급구호'],
#   ['돋을새김', '밥', '한', '그릇의', '무게'],
#   ['씨줄날줄', '우리쌀의', '살길'],
#   ['서울시', '반지하', '주택', '골목길에', '침수경보시설', '설치'],
#   ['소금물로',
#    '눈',
#    '씻기',
#    '인공눈물',
#    '많이',
#    '쓰면',
#    '좋다',
#    '결막염',
#    '안구건조',
#    '대처법',
#    '오해와',
#    '진실'],
#   ['롯데월드', '어드벤처', '8년', '연속', '실내공기질', '인증', '획득'],
#   ['2020년생', '83', '는', '평생', '극한폭염', '아이들이', '기후빚', '떠안는다'],
#   ['예측', '못한', '폭우', '대비', '서울시', '반지하', '골목', '침수', '경보', '시스템', '도입'],
#   ['행안부', '재난안전산업', '진흥시설', '조성', '지원사업', '부산시', '선정'],
#   ['이철우', '정부는', '포항시민들에게', '사과하고', '신속', '보상해야'],
#   ['대프리카', '대구', '15일부터', '폭염', '대비', '응급실', '감시체계', '돌입'],
#   ['중국서', '베테랑', '드론', '조종사', '이기는', 'ai', '자동', '드론', '나와'],
#   ['이철우', '경북지사', '정부', '포항지진', '신속', '보상해야'],
#   ['침대로', '막아봤지만', '폼페이', '최후의', '날', '에', '드러난', '가족의', '사투'],
#   ['한국지방재정공제회',
#    'lofa',
#    '산불',
#    '피해',
#    '지원',
#    '위해',
#    '대한적십자사에',
#    '성금',
#    '5천만',
#    '원',
#    '기부'],
#   ['포항시', '산풀', '피해', '이재민', '돕기', '집중', '모금', '총', '41억', '5210만원', '상당'],
#   ['롯데월드만', '가면', '상쾌한', '이유', '있었네', '8회', '연속', '받은', '그', '인증'],
#   ['이탈리아', '모든', '기업', '기후보험', '가입', '의무화'],
#   ['재난대응', '안전한국훈련', '오늘부터'],
#   ['일상', '속', '지진', '재난', '대응법', '배워요'],
#   ['재난대응', '안전한국훈련', '오늘부터'],
#   ['서울', '반지하', '밀집', '지역', '15곳', '골목에', '침수', '경보', '시스템', '설치한다'],
#   ['구로구', '2025년', '여름철', '종합대책', '수립', '폭염', '침수', '감염병', '등', '선제', '대응'],
#   ['서울시', '풍수해', '대책', '가동', '전국', '최초', '반지하', '침수경보시설', '도입'],
#   ['침대로',
#    '막고',
#    '사투',
#    '벌였지만',
#    '폼페이',
#    '최후의',
#    '날',
#    '숨진',
#    '가족의',
#    '비극',
#    '핵잼',
#    '사이언스'],
#   ['세계',
#    '어린이',
#    '4000만명',
#    '살릴',
#    '방법',
#    '2100년',
#    '기온상승폭',
#    '1',
#    '5도',
#    '내로',
#    '막아야'],
#   ['반지하', '골목', '침수경보', '전국', '첫', '가동', '서울시', '풍수해', '선제', '대응'],
#   ['구로구', '여름철', '종합대책', '수립', '폭염', '침수', '감염병', '등', '선제', '대응'],
#   ['집안에서', '자주', '쓰는데', '변기보다', '세균', '75배', '많은', '이', '가구'],
#   ['매일', '뒹구는', '이곳', '변기보다', '세균', '75배', '많다'],
#   ['전세계', '사망원인', '1위', '가슴', '조여오는', '이', '병', '꾸준한', '운동이', '도움', '건강'],
#   ['미국', '대도시들이', '매년', '수', '씩', '가라앉고', '있다'],
#   ['중국', '티베트서', '규모', '5', '5', '지진', '피해', '상황', '조사', '중'],
#   ['굿피플', '미얀마', '지진', '피해', '지역서', '긴급구호', '진행'],
#   ['소년중앙', '유익균', '유산균', '프로바이오틱스', '제대로', '알면', '장', '건강에', '도움', '돼요'],
#   ['포탄인', '줄', '연천', '지진에', '주민들', '화들짝'],
#   ['오늘의', '날씨', '오전', '2025년', '05월', '12일'],
#   ['외출', '30분', '전이', '핵심', '세월', '비껴가는', '피부', '만드는', '법', 'health'],
#   ['health',
#    '폐암',
#    '4기',
#    '환자',
#    '암세포',
#    '완전히',
#    '사라져',
#    '레이저티닙',
#    '새',
#    '치료',
#    '기준',
#    '되나'],
#   ['기후변화로', '세계', '인프라', '재해', '급증', '법', '바꿔서라도', '온실가스', '감축해야'],
#   ['경북', '산불', '전소', '주택에', '최소', '1억원', '이상', '지원'],
#   ['신현길의', '뭐든지', '예술활력', '재난을', '대하는', '예술의', '자세'],
#   ['경북산불',
#    '전소주택',
#    '지원금',
#    '1억',
#    '원',
#    '이상',
#    '경북도',
#    '대형',
#    '산불',
#    '피해',
#    '복구',
#    '신속',
#    '지원'],
#   ['행안부', '재난대응', '안전한국훈련', '실시', '풍수해', '지진', '등', '대비'],
#   ['인천까지', '흔들린', '연천', '지진', '규모', '3', '3', '반경', '50', '최대', '규모'],
#   ['재난에',
#    '안전한',
#    '대한민국',
#    '만들어요',
#    '상반기',
#    '안전한국훈련',
#    '12',
#    '23일',
#    '103개',
#    '기관',
#    '실시'],
#   ['경북도', '초대형', '산불', '복구', '올해', '정부', '추경', '1조원', '확보', '추가', '반영', '추진'],
#   ['이달', '강수량', '평년과', '비슷', '6개월', '누적', '강원', '영동', '경상', '전남', '기상가뭄'],
#   ['포항', '지진', '책임', '정부', '오리발', '시민들', '억지', '주장', '너무', '화가', '나'],
#   ['관중', '사망사고', '난', '창원nc파크', '이르면', '이달', '재개장', '한다'],
#   ['산불', '아픔', '딛고', '새롭게', '도약하는', '전화위복의', '계기로'],
#   ['혈관에', '조용히', '쌓이는', '미세먼지', '132만명', '생명', '위협한다'],
#   ['무단결근', '의무', '독특한', '규칙', '만든', '日기업에', '생긴', '놀라운', '일', '세계', '한잔'],
#   ['오늘의', '날씨', '오전', '2025년', '05월', '11일'],
#   ['놀면서', '보조금', '못받자', '또라이', '아르헨', '아직', '페로니즘', '잔향'],
#   ['경기', '연천서', '규모', '3', '3', '2', '5', '지진', '잇따라', '수도권', '흔들림'],
#   ['경기',
#    '연천서',
#    '규모',
#    '3',
#    '3',
#    '지진',
#    '이후',
#    '2',
#    '5',
#    '지진',
#    '잇따라',
#    '수도권',
#    '흔들림',
#    '감지'],
#   ['경기', '연천서', '규모', '3', '3', '지진', '수도권', '강원', '곳곳', '흔들림'],
#   ['경기', '연천군', '규모', '3', '3', '지진', '강원', '경기', '인천서', '흔들림', '느낄', '수도'],
#   ['경기', '연천서', '규모', '3', '3', '지진', '발생', '수도권', '곳곳', '진동', '감지'],
#   ['기상청', '경기', '연천', '북북동쪽서', '규모', '3', '3', '지진', '발생'],
#   ['기상청', '경기', '연천', '북북동쪽', '5km', '규모', '3', '3', '지진', '발생'],
#   ['속보', '기상청', '경기', '연천', '북북동쪽서', '규모', '3', '3', '지진', '발생'],
#   ['기상청', '경기', '연천', '북북동쪽서', '규모', '3', '3', '지진', '발생'],
#   ['속보', '경기', '연천군에서', '규모', '3', '3', '지진'],
#   ['경기도', '연천', '북북동쪽', '5', '지역', '규모', '3', '3', '지진', '발생'],
#   ['경기', '연천에서', '규모', '3', '3', '및', '2', '5', '지진', '잇따라', '발생'],
#   ['경기', '연천', '북북동쪽서', '규모', '3', '3', '지진', '기상청'],
#   ['속보', '연천', '북북동쪽서', '규모', '3', '3', '지진', '발생'],
#   ['기상청', '경기', '연천', '북북동쪽서', '규모', '3', '3', '지진', '발생'],
#   ['기상청', '경기', '연천', '북북동쪽서', '규모', '3', '3', '지진', '발생'],
#   ['때리는',
#    '소리부터',
#    '달랐다',
#    '한국',
#    '남자',
#    '배구',
#    '전성기',
#    '이끈',
#    '아시아',
#    '거포',
#    '강만수',
#    'k스포츠',
#    '레전드',
#    '열전'],
#   ['포토', '카페', '틈의', '힘'],
#   ['관중사망', '창원nc파크', '시설물', '정비', '후', '이달', '재개장'],
#   ['재난', '당해도', '다시', '일어설', '수', '있게', '이재명의', '안전', '공약'],
#   ['이재명', '재난', '당해도', '일어날', '수', '있는', '대한민국', '만들', '것'],
#   ['이재명', '국민', '생명에', '과잉', '대응', '없다', '재해', '재난', '공약', '발표'],
#   ['행안부', '하천', '범람', '대비', '안전관리', '대책', '점검'],
#   ['지진', '복구', '휴전', '선언에도', '미얀마', '내전', '격화', '군정', '전국', '200차례', '공습'],
#   ['올해의', '공항', '라운지', '에', '브라질', '어드밴티지', 'vip', '라운지', '선정'],
#   ['메콩', '센강', '연결수로', '사업', '등', '캄보디아', '물시장', '진출'],
#   ['농식품부', '농어촌공사', '한국형', '모델', '로', '라오스', '댐', '안전관리', '시스템', '기술지원'],
#   ['동해시', '여름철', '자연재난', '대응체계', '본격', '가동'],
#   ['마스크도', '못', '막는다', '미세먼지', '아닌', '이것', '의', '정체'],
#   ['2020년생', '절반', '평생', '역대급', '폭염', '시달릴', '것'],
#   ['klpga', '산불', '피해복구', '기금', '2000만원', '전달'],
#   ['한울본부', '방사능방재', '전체훈련', '시행'],
#   ['기후의', '미래', '유채꽃과', '기름전쟁'],
#   ['김봉석의', '문화유랑', '지구의', '해피엔드'],
#   ['대기오염물질', '더', '민감하고', '안정적으로', '감지한다'],
#   ['환경부', '캄보디아', '물시장', '진출', '교두보', '확보', '양국', '물협력', '본격', '추진'],
#   ['서부산권', '외국인', '노동자', '안전', '처우개선', '위해', '뭉친', '하이파이브'],
#   ['신고전주의', '미술은', '국가권력과', '민중계몽의', '도구였다'],
#   ['폭우', '폭염에도', '빈틈없는', '도봉', '4대', '분야', '16개', '대책', '다', '짜놨다'],
#   ['klpga', '영남', '산불', '피해', '복구', '지원', '위해', '2천만', '원', '전달'],
#   ['산림과학원', '도시숲', '폭염', '미세먼지', '및', '호흡기', '질환', '감소', '효과'],
#   ['창원nc파크', '올해', '재개장', '오리무중', '홈', '경기는', '울산', '문수야구장서'],
#   ['nc다이노스', '울산서', '홈경기', '창원구장', '올해', '재개장', '어려워'],
#   ['캄보디아', '물관리', '시장', '韓', '진출', '교두보', '환경부', '사절단', '활약'],
#   ['경주서', '어젯밤', '두차례', '지진', '규모', '2', '0', '2', '5', '피해신고', '없어'],
#   ['간밤', '두', '차례', '흔들린', '경주', '큰', '지진으로', '이어질', '가능성은', '적어'],
#   ['7일',
#    '밤',
#    '경주서',
#    '두',
#    '차례',
#    '지진',
#    '발생',
#    '2016년',
#    '규모',
#    '5',
#    '8',
#    '지진',
#    '진앙',
#    '근처'],
#   ['전국', '화창한', '어버이날', '한낮', '26도', '초여름', '더위'],
#   ['경북', '경주서', '규모', '2', '0', '2', '5', '지진', '잇달아'],
#   ['경북', '경주서', '수차례', '지진', '이어져', '2016년', '최대', '지진', '발생', '인근'],
#   ['①', '결혼', '안', '한', '여자는', '혼자', '늙어', '죽는다고', '플랫', '에프워드'],
#   ['도봉구', '여름철', '종합안전망', '가동'],
#   ['경주서', '두', '차례', '지진', '2016년', '규모', '5', '8', '지진', '진앙', '근처'],
#   ['생태적', '범죄', '강제점령', '아픔에', '공감', '이스라엘', '질타한', '37개', '나라', '사이월드'],
#   ['오늘의', '날씨', '오전', '2025년', '05월', '08일'],
#   ['부천시민이라면', '누구나', '심폐소생술', '할', '수', '있게'],
#   ['작년', '보험사', '해외점포', '흑자전환', '순익', '1', '6억', '달러'],
#   ['경주서', '두', '차례', '지진', '2016년', '규모', '5', '8', '지진', '진앙', '근처'],
#   ['핵무기', '쥔', '인도', '파키스탄의', '위험한', '대결', '전쟁', '또', '터지나'],
#   ['경주서', '두', '차례', '지진', '규모', '2', '0', '2', '5', '연달아', '발생'],
#   ['김상훈의', '제5영역', '미신이', '현실이', '될', '때'],
#   ['기상청', '경북', '경주', '남서쪽서', '규모', '2', '5', '지진', '발생', '피해', '없어'],
#   ['월성본부', '다수', '호기', '월성3호기', '신월성1호기', '방사능방재', '전체훈련', '실시'],
#   ['경북', '경주', '남서쪽서', '규모', '2', '0', '지진', '피해', '없을', '듯'],
#   ['호우', '폭염', '강풍', '더', '강해진다', '올여름', '복합재해', '주의보'],
#   ['경북', '경주서', '밤사이', '지진', '두', '차례', '진동', '느낄', '수', '있어'],
#   ['복음', '붙드는', '손', '놓지', '않도록', '아시안미션', '지진', '피해', '선교사', '돕기', '나서'],
#   ['기고', '여름', '배추', '수급', '불안', '기술로', '푼다'],
#   ['올여름', '장마', '심상치', '않다', '예상치', '못한', '일', '발생해도', '놀랍지', '않을', '것'],
#   ['부천시', 'cpr', '교육', '효과', '톡톡', '학교서', '배운', '심폐소생술로', '엄마', '살렸다'],
#   ['경북', '초대형', '산림분야', '산불피해', '복구비', '8658억', '신속', '지원'],
#   ['경기도', '농작물재해보험', '지원', '강화', '기후위기', '선제', '대응'],
#   ['하동', '순찰차', '뒷좌석', '사망사고', '부실', '근무', '경찰관', '2명', '송치'],
#   ['하동', '순찰차', '사망', '사건', '9개월', '만', '수사', '결과', '2명', '송치', '그쳐'],
#   ['하동', '순찰차', '사망사고', '경찰', '2명', '검찰', '송치', '13명', '징계위', '회부'],
#   ['미국과', '관세', '실무협상', '중인', '일본', '쌀에', '손', '대면', '정권', '무너진다'],
#   ['하동', '순찰차', '내', '여성', '사망', '사건', '관련', '경찰', '15명', '중', '2명만', '송치'],
#   ['하동', '순찰차', '사망', '사건', '경찰관', '2명', '직무유기', '등', '송치'],
#   ['대도시가', '매년', '31', '씩', '꺼져', '싱크홀', '충격', '결국', '수도이전', '말', '나온', '나라'],
#   ['파시즘이', '닥친', '세계', '해피엔드', '네오', '소라', '감독의', '예지력을', '질투하다'],
#   ['학교서', '배운', 'cpr로', '엄마', '살려', '부천시', 'cpr', '교육', '효과'],
#   ['사실상', '핵보유국', '인도', '파키스탄', '또', '군사충돌', '전면전', '가능성은'],
#   ['용산구', '취약계층', '순회', '안전교육', '실시'],
#   ['평소', '배운', '심폐소생술로', '엄마', '살렸어요', '응급처치', '교육에', '힘쏟는', '부천시'],
#   ['충남도', '인삼', '생육', '초기', '투과량', '20', '유지해야'],
#   ['경기도', '농작물재해보험', '가입', '지원', '확대'],
#   ['기후위기', '농가', '피해', '줄이자', '경기도', '농작물재해보험', '지원', '강화'],
#   ['서초구', '여름철', '풍수해', '대비', '옥외광고물', '안전점검', '실시'],
#   ['오늘의', '날씨', '오전', '2025년', '05월', '07일'],
#   ['연', '3000만원', '연금', '탈', '거라면', '126만원', '덜', '내는', '절세팁', '6종', '연금술사⑩'],
#   ['50년', '전', '정책이', '산불', '키웠다', '박완수', '보존서', '적극적', '관리로', '바꿀', '때'],
#   ['무더위', '성큼', '도심', '그늘막', '활동', '개시'],
#   ['산림의', '두', '얼굴', '든든한', '탄소', '흡수원', '재난', '땐', '탄소', '배출원', '돌변'],
#   ['탄소', '줄이고', '고농도', '오존', '감축', '도봉', '자연', '주민', '건강', '다', '지킨다'],
#   ['전기', '수요', '느는데', '신규', '인력은', '부족', '특급', '감리', '자격', '기술사', '제한', '풀어야'],
#   ['쿵', '소리만', '나도', '화들짝', '포항지진', '고위험군', '16'],
#   ['트럼프', '의약품', '관세도', '초읽기', '韓기업', '예의주시', '재고', '확보'],
#   ['전기', '수요', '느는데', '현장은', '고령화', '특급', '감리', '제도', '개선', '절실'],
#   ['대전시', '여름', '재난', '대비', '내달', '18일까지', '자연재난', '감찰', '실시'],
#   ['춘천시', '폭염', '대비', '선제적', '대응', '도심', '5곳에', '폭염저감시설', '설치'],
#   ['단독',
#    '포항',
#    '지진',
#    '7년',
#    '트라우마',
#    '못',
#    '벗어나는',
#    '시민들',
#    '정상',
#    '은',
#    '1',
#    '5',
#    '뿐'],
#   ['포토타임', '매주', '금', '토', '일', '광화문', '의정부터서', '조선', '전통무예', '시연'],
#   ['회색빛', '도시', '풍경', '속', '반짝이는', '기억의', '편린'],
#   ['천식약', '먹으면', '키', '안', '큰다', '영향', '미미'],
#   ['강주안', '논설위원이', '간다', '모든', '정신질환', '살인', '범죄엔', '전조', '증상', '있었다'],
#   ['대형', '지진', '태풍', '대비', '범정부', '신속', '대응', '시스템', '구축', '필요'],
#   ['규모', '5', '4', '지진이', '흔든', '시민', '삶', '도시재생과', '함께', '되살아난', '포항'],
#   ['광화문에서', '홍정수', '보냈지만', '닿지', '못한', '지원', '미얀마에', '5월은', '잔인한', '달'],
#   ['태안', '앞바다', '3', '7', '지진', '수도권서도', '일부', '느껴'],
#   ['홍성욱의', '과학', '오디세이', '80', '패권', '경쟁', '시대엔', '과학', '외교', '를'],
#   ['대만',
#    '동부',
#    '해역서',
#    '규모',
#    '5',
#    '9',
#    '지진',
#    '2024년',
#    '강진',
#    '화롄',
#    '일대',
#    '5차례',
#    '여진',
#    '발생'],
#   ['하다하다', '짝퉁', '후지산', '만든', '중국', '관광지', '짝퉁', '에펠탑', '스핑크스도', '논란'],
#   ['따뜻하면', '산림', '회복', '빠르다고', '대형', '산불', '회복', '공식', '달라졌다'],
#   ['전국', '첫', '시행', '경기도', '기후보험', '첫', '수혜자는', '말라리아', '환자'],
#   ['5월', '분양시장에', '큰', '장', '선다', '수도권', '1만여', '가구', '쏟아져'],
#   ['흰', '페인트', '칠하고', '가짜', '화산', '폭발쇼', '中', '짝퉁', '후지산', '논란'],
#   ['언덕에', '흰', '페인트칠', '짝퉁', '후지산', '만든', '中관광지', '빈축'],
#   ['충남', '태안', '해상서', '올', '들어', '가장', '큰', '규모의', '지진', '발생', '피해는', '없어'],
#   ['태안', '인근', '바다', '지진으로', '흔들림', '신고', '16건', '피해신고', '없어'],
#   ['작은', '언덕에', '페인트칠', '정말이지', '후지다', '난리', '난', '中짝퉁', '후지산'],
#   ['충남', '태안', '북서쪽', '인근', '바다서', '규모', '3', '7', '지진'],
#   ['속보',
#    '충남',
#    '태안',
#    '해역서',
#    '규모',
#    '3',
#    '7',
#    '지진',
#    '인근',
#    '지역',
#    '지진동',
#    '느낄',
#    '수',
#    '있어'],
#   ['충남', '태안', '북서쪽', '해역서', '규모', '3', '7', '지진', '발생'],
#   ['충남', '태안', '해역에서', '규모', '3', '7', '지진', '인근', '지역', '진동'],
#   ['충남', '태안', '북서쪽', '인근', '바다서', '규모', '3', '7', '지진'],
#   ['충남', '태안군', '북서쪽', '52', '해역서', '규모', '3', '7', '지진'],
#   ['속보', '태안', '해역서', '규모', '3', '7', '지진', '발생', '올해', '지진', '중', '가장', '강해'],
#   ['속보', '충남', '태안', '북서쪽', '인근', '바다서', '규모', '3', '7', '지진', '기상청', '안전유의'],
#   ['속보',
#    '충남',
#    '태안',
#    '해역서',
#    '규모',
#    '3',
#    '7',
#    '지진',
#    '올해',
#    '최대',
#    '규모',
#    '6건',
#    '신고',
#    '접수'],
#   ['7시53분', '충남', '태안군', '북서쪽', '52', '해역서', '규모', '3', '7', '지진', '발생'],
#   ['제발',
#    '퇴사만은',
#    '레드카펫에',
#    '특급열차',
#    '대령',
#    '신입에게',
#    '매력',
#    '어필하는',
#    '일본',
#    '기업들',
#    '클로즈업',
#    '재팬'],
#   ['김대일',
#    '경북도의원',
#    '경북',
#    '북부권',
#    '산불',
#    '한',
#    '달',
#    '복구',
#    '지연에',
#    '지역은',
#    '무너지고',
#    '있다'],
#   ['유엔', '미얀마군', '강진', '이후', '243회', '공격', '민간인', '200여명', '사망'],
#   ['기후', '번역가', '언론이', '잊어선', '안', '될', '것', '김형준의', '메타어스'],
#   ['우리', '차례는', '언제', '올까', '플랫'],
#   ['中', '짝퉁', '후지산', '실체는', '1만', '9000원', '입장료에', '관광객', '분노', '사기당했다'],
#   ['약', '먹으면', '키', '안', '큰다', '운동은', '금물', '소아', '천식', '오해와', '진실'],
#   ['강원', '삼척시', '부근', '바다서', '규모', '2', '2', '지진', '발생', '피해는', '없어'],
#   ['기상이변에', '대규모', '정전까지', '뒤숭숭', '관광대국', '스페인', '비상'],
#   ['고리타분한', '박물관은', '가라', '경기도', '이색', '박물관'],
#   ['사실상',
#    '사망선고',
#    '받았던',
#    '가수',
#    '유열',
#    '폐이식',
#    '후',
#    '삶',
#    '을',
#    '찾았다',
#    '병을',
#    '이겨내는',
#    '사람들'],
#   ['칠레', '남부', '해역서', '7', '4', '강진', '일부', '남극', '연구시설에', '대피령'],
#   ['칠레', '남부', '해역서', '7', '4', '강진', '일부', '남극', '연구시설에', '대피령'],
#   ['중대본', '영남권', '산불', '피해액', '1조818억', '역대', '최대'],
#   ['중대본', '영남권', '산불', '피해액', '복구비', '역대', '최대', '1조8809억원', '지원'],
#   ['중대본', '영남권', '산불', '피해액', '1조818억', '복구비', '1조8809억', '확정'],
#   ['역대', '최대', '피해', '남긴', '영남산불', '피해액', '1조800억원', '규모'],
#   ['속보', '중대본', '영남권', '산불', '피해액', '1조818억', '복구비', '1조8809억'],
#   ['이주호',
#    '대행',
#    '경북',
#    '경남',
#    '울산',
#    '산불',
#    '피해',
#    '복구',
#    '계획',
#    '확정',
#    '연휴',
#    '안전사고',
#    '대비'],
#   ['중대본', '영남권', '산불', '피해', '복구비', '사상', '최대', '피해액', '1조818억'],
#   ['가평군', '홍수', '폭염', '태풍', '대비', '여름', '오기', '전', '미리미리'],
#   ['이제', '침수피해는', '그만', '익산시', '산북천', '침수피해', '지역', '공사', '본격', '추진'],
#   ['환경부', '산불', '홍수', '싱크홀', '대응에', '추경', '2414억', '확정'],
#   ['포토타임', '선글라스', '낀', '유생들', '경희궁', '별별유생', '체험'],
#   ['구름', '끼고', '칼바람', '쌩', '15도', '이상', '큰', '일교차', '주의'],
#   ['2025',
#    '중앙',
#    'esg',
#    '경영대상',
#    '초격차',
#    '기술로',
#    '친환경',
#    '물관리',
#    '실현',
#    '글로벌',
#    '기후',
#    '테크',
#    '기업으로',
#    '도약'],
#   ['2030년',
#    '국산',
#    'smr',
#    '추진선',
#    '뜬다',
#    '발전량',
#    '조절',
#    '핵연료',
#    '처리가',
#    '난제',
#    '테크',
#    '인사이트'],
#   ['장정', '넷이', '들어도', '꿈쩍않고', '산불속', '절', '지킨', '부처님'],
#   ['한삼희의', '환경칼럼', '팽창하는', '에어', '스펀지', '산불은', '더', '크게', '날', '수밖에'],
#   ['산불', '연기', '조심해야', '노출된', '노인층', '호흡기', '질환', '입원', '증가'],
#   ['기상청', '국가기후예측시스템', '개발', '착수', '2031년까지', '495억원', '투입'],
#   ['재발화했던', '대구', '함지산', '산불', '무서운', '봄바람', '이', '확산', '원인'],
#   ['제주', '당근연합회', '출범', '10주년', '구좌당근', '명품', '도약에', '큰', '힘'],
#   ['일본', '홋카이도', '도마리원전', '안전성', '우려', '불구', '재가동'],
#   ['경기관광공사', '태국에', '대표사무소', '개소'],
#   ['아직', '이재민만', '5만', '명인데', '휴전', '끝내고', '전투', '재개한', '미얀마', '군부'],
#   ['경기관광공사', '태국', '사무소', '개소', '동남아', '시장', '공략', '강화'],
#   ['호반그룹',
#    '봉사활동과',
#    '기부로',
#    '사회에',
#    '온기',
#    '임직원',
#    '봉사단',
#    '누적',
#    '기부금',
#    '10억원',
#    '달성'],
#   ['魚', '잡혔네', '서툰', '강태공도', '47', '도다리', '월척', '낚았다', '박경일기자의', '여행'],
#   ['우리', '강물', '쓰지', '마', '타들어가는', '세계', '각국', '물', '전쟁', 'global', 'focus'],
#   ['광진구', '집중호우', '대비', '육갑문', '개폐', '훈련', '시행'],
#   ['부모', '중', '한', '명', '알레르기', '비염이면', '자녀', '20', '가', '같은', '질환', '앓는다'],
#   ['불길', '닥친', '밤', '부처님은', '대웅보전', '지켰다', '천년고찰의', '신비'],
#   ['사랑방', '한국sgi', '미얀마에', '지진피해', '구호', '후원'],
#   ['남지원의', '다른', '시선들', '우리', '차례는', '언제', '올까'],
#   ['경기관광공사', '태국', '현지', '사무소', '문', '열어', '지방관광공사', '최초', '도전'],
#   ['한국sgi', '미얀마', '지진', '피해', '구호', '후원금', '유엔난민기구에', '기탁'],
#   ['기후대응댐', '유익시설인가요', '유해시설인가요'],
#   ['경주', '천월사', '산불피해', '성금', '100만원', '기탁', '이재민', '일상', '회복되길'],
#   ['경기관광공사', '태국에', '대표사무소', '개소', '동남아', '공략'],
#   ['이런', '박물관도', '있었어', '경기관광공사', '경기도', '이색박물관', '6곳', '추천'],
#   ['서부발전', '네팔', '온실가스', '감축사업으로', 'rec', '확보'],
#   ['서부발전', '네팔위한', '온실가스', '감축'],
#   ['폭염', '산불', '가뭄', '심해지는데', '트럼프', '기후변화', '보고서', '연구진', '전원', '해임'],
#   ['경남도', '해양수산분야', '기후변화', '대책', '추진해', '위기', '극복한다'],
#   ['한강청', '홍수대비', '합동', '모의훈련', '홍수기', '주민', '안전', '물샐틈없이', '지킨다'],
#   ['지난해', '낙뢰', '14만5000회', '경북에', '가장', '많이', '떨어졌다'],
#   ['트럼프', '화석연료', '회귀에도', '탈탄소', '흐름은', '이어질', '것'],
#   ['5월의', '독립운동에', '여성', '지위', '향상', '외친', '근우회', '창립', '선정'],
#   ['박서준', '기부금', '후원으로', '뇌종양', '환아', '살렸다', '우리', '가족에', '희망', '줘', '감사'],
#   ['박서준', '기부로', '뇌종양', '앓는', '아들이', '수술', '받아', '희망', '생겼어요'],
#   ['big', 'change', 'kaist와', '함께', '중학생', '대상', '우주', '교육', '운영'],
#   ['오늘의', '날씨', '오전', '2025년', '04월', '30일'],
#   ['이상기후', '습격', '스페인', '극심한', '기온', '변화에', '송전선', '손상돼', '정전', '가능성'],
#   ['10대', '용접공이', '50대', '달인', '되는', '사이', 'k잠수함도', '세계', '톱8', '됐다'],
#   ['윤', '파면', '거치며', '사회가', '어떤', '성찰', '하나', '보여줬어야'],
#   ['급식실서', '볶고', '튀기다', '폐암', '진단', '10년', '근무', '채워야', '산재라니'],
#   ['박서준', '후원', '덕에', '무사히', '아이', '수술', '뇌종양', '환자', '부모의', '손편지'],
#   ['군부', '구호', '물품', '막고', '시신', '부상자', '방치', '미얀마', '날마다', '절규'],
#   ['미얀마', '지진', '피해', '명지전문대', '유학생', '돕기', '나섰다'],
#   ['기후위기', '시대', '천재지변', '보상', '안', '한다', '는', '보험', '약관', '시민단체', '불공정'],
#   ['과기부', '통신', '정비사업', '2단계', '착수', '거리', '미관', '안전', '환경', '개선'],
#   ['마스크로', '못', '막는', '오존', '도봉은', '아예', '발생을', '막는다'],
#   ['김대일', '경북도의원', '경북', '북부권', '산불', '한', '달', '복구', '지연에', '지역은', '무너져'],
#   ['미얀마', '강진', '한', '달', '시신', '수습도', '아직', '국제사회', '관심', '꺼질까', '두렵다'],
#   ['호주', '코알라', '700마리', '살처분한', '이유는'],
#   ['깨끗한나라', '프리미엄', '웰니스', '브랜드', 'better', '3종', '마켓컬리', '론칭'],
#   ['여행자보험', '실손보험과', '중복', '보장', '안됩니다'],
#   ['산림청',
#    '영남지역',
#    '산불피해',
#    '복구',
#    '추진단',
#    '구성',
#    '연말까지',
#    '지역별',
#    '복구',
#    '복원',
#    '계획',
#    '수립'],
#   ['스마트', '비가림', '시설', '이상저온', '속', '사과', '지켜냈다'],
#   ['오존경보때', '낡은', '건설기계', '제한'],
#   ['월성본부', '동경주', '경로당에', '건강증진물품', '지원'],
#   ['이상기후', '습격', '스페인', 'off'],
#   ['서울', '싱크홀', '3건중', '1건은', '강남', '송파', '강동서', '폭삭'],
#   ['성동구', '반지하', '옥탑방', '가구에', '벽걸이', '에어컨', '지원', '냉난방꾸러미', '중', '선택', '가능'],
#   ['도봉구', '고농도', '오존', '관리', '특별', '대책', '시행'],
#   ['상주시', '국비', '확보로', '가뭄대비', '용수개발사업', '본격', '추진'],
#   ['민주', '행안위서', '지역화폐', '1조', '추경안', '단독', '처리'],
#   ['해외', '곳곳서', '산불', '성금', '6500만원', '모금'],
#   ['포항지진', '손배소', '항소심', '내달', '선고', '1', '5조', '배상금', '터지나'],
#   ['공직자의', '창', 'ai', '활용으로', '기후', '위기에도', '안전한', '여름을'],
#   ['팔순의', '어머니', '새벽녘', '콜록콜록', '감기', '방심했다', '폐렴', '평생', '땅', '치고', '후회'],
#   ['기상청', '여수', '거문도', '남동쪽', '바다서', '2', '7', '지진', '피해', '없을듯'],
#   ['한화그룹', '함께', '멀리', '철학', '바탕', '장기', '다채', '사회공헌활동', '펼쳐'],
#   ['7월', '日', '대지진설', '퍼지자', '주일', '中대사관', '유학도', '부동산', '구입도', '조심'],
#   ['하남시', '전국', '최초', '스마트', '그늘막', '전용도시', '완성', '전', '구간', '100', '전환'],
#   ['민주', '지역화폐', '1조원', '추경안', '단독', '의결', '국민의힘', '퇴장'],
#   ['경북도', '장마철', '대비', '산불지역', '132곳에', '응급복구', '총력'],
#   ['한수원', '월성본부', '가정의', '달', '앞두고', '경로당', '물품지원'],
#   ['ai', '기반', '산사태', '피해저감', '기술', '개발한다', '임업진흥원', 'ai', '기업', '협약'],
#   ['폭염', '대응', '선도', '하남시', '전국', '최초', '100', '스마트', '그늘막', '전환'],
#   ['전남도', '산사태', '재난대응', '훈련', '주민대피', '시스템', '점검'],
#   ['산불', '덮친', '영덕', '노물리항', '일대', '해양관광마을로', '거듭난다', '전체', '재건'],
#   ['과거사', '반성', '안', '하는', '일본', '미래는', '일본', '사회', '비판', '감독', '누구'],
#   ['2차', '피해는', '막아야', '경북도', '산사태', '피해', '예방에', '총력'],
#   ['주일', '中대사관', '규모9', '난카이대지진', '대비', '부동산', '구입', '신중해야'],
#   ['中', '자국민에', '日', '대지진', '경고', '여행', '부동산', '신중하라'],
#   ['지진', '틈타', '득세하는', '일본', '극우', '소라', '네오가', '상상한', '근미래', '우정은', '흔들린다'],
#   ['동아대', '연구팀', '세계', '최초로', '초미세먼지가', '인체에', '축적되는', '기전', '규명'],
#   ['kb국민카드', '산불지역', '묘목', '기부'],
#   ['소나무', '등', '단순림이', '전세계', '산불', '키워'],
#   ['폭염', '시', '부모', '돌봄이', '자녀에게', '미치는', '영향을', '밝히다'],
#   ['산불에', '살', '곳', '잃은', '코알라', '700마리', '사살한', '호주', '정부', '논란'],
#   ['영주시', '여름철', '재난', '대비', '체계', '점검', '재난', '대응', '역량', '강화'],
#   ['사', '경북해외자문위원협의회', '경북', '산불', '피해', '성금'],
#   ['문성호',
#    '서울시의원',
#    '시민',
#    '통행권',
#    '침해에',
#    '공사',
#    '직원',
#    '폭행까지',
#    '전장연은',
#    '그릇된',
#    '시위방식',
#    '중단하라'],
#   ['지하', '핵실험', '자연지진에', '가려질', '수', '있다', '美', '연구진', '연구', '결과', '발표'],
#   ['산불피해', '영덕', '노물리', '명품', '해양관광마을로', '재건된다'],
#   ['오늘의', '날씨', '오전', '2025년', '04월', '28일'],
#   ['단독', '산불에', '호흡기', '질환보다', '심질환', '위험', '더', '커'],
#   ['기억할', '오늘', '인신공양', '풍습과', '아스테카', '마야', '잉카', '문명'],
#   ['괴물', '산불', '예고된', '재난', '기후', '변화가', '불쏘시개', '대응', '체계', '재설계해야', '월요인터뷰'],
#   ['산불', '피해', '입은', '내', '고향', '내가', '살려요'],
#   ['7월', '일본', '대지진설', '홍콩발', '항공편', '수요', '뚝'],
#   ['산불로', '전소된', '영덕', '노물리', '명품', '관광마을로', '거듭난다'],
#   ['균열된', '우정의', '끝은', '소라', '네오', '감독이', '그리는', '해피엔드'],
#   ['경북산불로', '초토화한', '영덕', '해안마을', '명품', '해양관광마을로', '재건'],
#   ['이상기후', '말이', '틀리면', '생각도', '틀린다', '김백민의', '해법기후'],
#   ['산불피해', '복구', '위해', '고향', '앞으로', '대구시', '안동', '등에', '공무원지원단', '파견'],
#   ['산불', '피해', '큰', '영덕', '노물리', '경북도', '복구', '넘어', '재건', '추진'],
#   ['인터뷰',
#    '미얀마',
#    '지진',
#    '한',
#    '달',
#    '한국',
#    '지원에',
#    '감사',
#    '혼자',
#    '아니다',
#    '느끼게',
#    '해',
#    '주길'],
#   ['고향마을', '살려야죠', '경북', '산불', '피해지역에', '대구공무원지원단', '파견'],
#   ['장흥군', '공공일자리', '43곳', '현장', '안전점검', '강화'],
#   ['배상금만', '무려', '1', '5조', '포항시민', '96', '가', '뛰어든', '이', '소송', '뭐길래'],
#   ['오늘의', '날씨', '오전', '2025년', '04월', '27일'],
#   ['美cia', '부국장', '아들', '러군', '자원해', '우크라전', '참전', '최전방서', '사망'],
#   ['cia', '부국장', '아들', '러시아군', '합류해', '우크라와', '싸우다', '전사'],
#   ['올여름', '日대지진', '소문에', '놀랐다', '日정부', '지진은', '예측', '불가'],
#   ['미', 'cia', '부국장', '아들', '러시아군으로', '우크라전', '참전했다가', '전사'],
#   ['美', 'cia', '부국장의', '21세', '아들', '러시아군에', '자원입대해', '싸우다', '전사'],
#   ['美', 'cia', '부국장의', '21세', '아들', '러시아군', '자원', '입대해', '우크라와', '싸우다', '전사'],
#   ['7월에', '진짜', '대재난', '온다', '족집게', '예언가가', '경고', '날린', '이곳', '충격', '근황'],
#   ['새로', '나온', '책', '지진의', '과학', '외'],
#   ['오늘의', '날씨', '오전', '2025년', '04월', '26일'],
#   ['어린이', '책', '화산서', '굴러온', '돌덩이가', '어쩌다', '민씨네', '복덩이로'],
#   ['새로', '나왔어요', '하얗지', '않은데', '왜', '백인인가', '外'],
#   ['기후악당', '책임', '따질', '새', '셈법', '111개', '기업이', '28조달러', '피해', '유발'],
#   ['봄철', '건강관리', '고용량', '비타민으로', '챙겨보자'],
#   ['봉천동',
#    '화재로',
#    '잿더미',
#    '된',
#    '살림살이',
#    '피해자',
#    '아들',
#    '완강기',
#    '스프링클러',
#    '있었다면',
#    '현장'],
#   ['네이버', '이제', '지도', '앱에서', '공공', '체육시설과', '회의실', '예약하세요'],
#   ['갑자기', '숨이', '턱', '100만명', '고통받는', '이병', '초기', '1년이', '중요'],
#   ['이재명', '양곡법', '개정해', '쌀값', '보장', '서울', '글로벌', '경제', '수도로'],
#   ['정부', '영남권', '산불', '피해', '지역', '우기', '전까지', '응급', '복구', '추진'],
#   ['네이버', '지도로', '축구장', '예약을', '공공시설', '예약', '기능', '도입'],
#   ['이재명', '양곡관리법', '개정', '재추진', '농업', '분야', '공약', '발표'],
#   ['이재명', '농정위기', '기회로', '바꿔', 'k', '농업강국', '도약', '양곡관리법도', '개정'],
#   ['이재명', 'k농업강국', '도약', '태양광', '햇빛연금', '확대', '양곡법', '개정'],
#   ['거대한', '대륙판의', '충돌', '지질', '문해력', '없인', '생존', '못한다', '북리뷰'],
#   ['생방송', '중', '엄마한테', '연락', '좀', '강진에도', '스튜디오', '자리', '지킨', '앵커'],
#   ['포항지진은', '국가', '재난', '정부책임', '인정을'],
#   ['신혼부부', '나무심기', '40년', '자작나무', '쓰러진', '자리에', '다시', '숲을', '만들다'],
#   ['삶의', '고통으로', '괴로울', '땐', '정직하게', '탄식하라'],
#   ['57년간', '韓', '바다', '온도', '상승', '지구', '평균의', '2배'],
#   ['포항', '지진', '손배소', '공정한', '판결해', '달라'],
#   ['책꽂이'],
#   ['포항지진은', '국가', '재난', '정부', '공식사과', '배상해야'],
#   ['한반도', '해역', '수온', '지구', '평균의', '2배', '상승', '수산과학원', '57년간', '1', '58도'],
#   ['이스탄불', '인근', '해상', '6', '2', '지진에', '150명', '부상', '세차례', '여진도'],
#   ['한국', '해역', '수온', '1', '58도', '지구', '2배', '속도', '생산성', '22'],
#   ['펄펄', '끓는', '바다', '지난해', '양식', '피해', '역대', '최대'],
#   ['경북도', '산불', '피해', '주민에', '공공형', '긴급', '일자리', '제공'],
#   ['산불피해지역', '여행은', '곧', '기부', '착한관광', '동참하세요'],
#   ['생방송', '중', '엄마에게', '연락', '좀', '지진에도', '벌벌', '떨며', '자리', '지킨', '앵커'],
#   ['韓', '수온', '상승', '속도', '지구보다', '2배', '빨라', '해양', '생산성', '악화', '현실화'],
#   ['생선값', '왜', '비싸졌나', '했더니', '고수온에', '해양', '생산력', '21', '감소'],
#   ['한', '대행', '산불', '이재민', '주거불편', '해소', '시급', '3700여명', '임시숙박'],
#   ['韓대행', '산불', '피해', '복구', '점검', '이달', '중', '이재민에', '국민', '성금', '전달', '지시'],
#   ['고통의', '순간', '하나님은', '어디', '있는가', '묻는', '이들에게'],
#   ['리퍼로', '스마트쇼핑', '맑은', '날씨', '안심하지마세요', '미세먼지', '황사의', '공포는', '여전히'],
#   ['국가', '책임', '인정해야', '포항지진', '항소심', '앞두고', '지역', '정치권', '한목소리'],
#   ['포항지진은', '국가적', '재난', '이강덕', '포항시장', '등', '입장문', '발표'],
#   ['산불지역에', '산사태', '우려', '경북도', '방어벽'],
#   ['저자본', '고보증', '구조에', '투기시장으로', '전락한', '부동산pf'],
#   ['금호건설', '결식아동', '지원', '1000만원', '초록우산에', '후원', '전달'],
#   ['한반도', '해역', '수온', '지구', '평균보다', '2배', '상승', '수산', '생태계', '자원', '악화', '뚜렷'],
#   ['포항지진은', '국가', '재난', '정부', '공식사과', '피해배상', '대책', '마련해야'],
#   ['포항지진은', '국가', '재난', '피해', '회복', '위한', '정부의', '책임', '있는', '대응', '촉구'],
#   ['소', '잃고', '외양간', '고치기', '그만', '전북소방', '축사', '화재', '맞춤형', '예방', '대책', '추진'],
#   ['인천대', '미얀마', '지진', '피해', '복구', '모금', '활동'],
#   ['트럼프발', '관세로', '이중고', '겪는', '독일', '맥주', 'eu', '주류업계', '강타'],
#   ['韓대행', '시정연설', '대한민국', '큰', '도전', '직면', '추경안', '조속히', '심의해달라'],
#   ['벚꽃', '터널', '끝이라고', '슬퍼마라', '샛노란', '유채', '계단', '이', '기다리니', '박경일기자의', '여행'],
#   ['사회적', '책임에', '앞장', '금호건설', '초록우산에', '결식아동', '지원', '후원금', '전달'],
#   ['김동연', '기후', '정책', '선도', '로컬', '리더즈', '선정', '한국인', '중', '유일'],
#   ['국민의',
#    '기업',
#    '기후변화',
#    '위협',
#    '속',
#    '안정적인',
#    '생산',
#    '위해',
#    '밀',
#    '콩',
#    '품종',
#    '개발에',
#    '앞장'],
#   ['불치병인', '줄', '알았는데', '엄마에게', '찾아온', '기적'],
#   ['ai가',
#    '산불',
#    '대피경로까지',
#    '알려준다',
#    '밴티크',
#    '주민들의',
#    '안전한',
#    '삶',
#    '돌보는',
#    'ai',
#    '시스템',
#    '도입',
#    '추진'],
#   ['최강', '흡입력과', 'ai로', '무장', '55도', '온수로', '얼룩도', '싹싹'],
#   ['김동연', '로컬', '리더즈', '11인', '선정', '유엔', '기후행동의', '선도적', '지방정부', '리더'],
#   ['시론', '자유무역과', '다자주의', '위협하는', '트럼프', '2기'],
#   ['온난화로', '극단적', '날씨', '잦아진다'],
#   ['이스탄불', '인근서', '규모', '6', '2', '지진', '주민들', '건물', '밖으로', '긴급', '대피'],
#   ['페브리즈', '따뜻한', '날', '스멀거리는', '집안', '냄새엔', '섬유탈취제'],
#   ['경북도', '장마철', '대비', '산불', '피해지역에', '옹벽', '등', '3중', '안전망', '구축'],
#   ['인도양', '순방', '나선', '마크롱', '해외', '영토령', '민심', '잡고', '중러', '패권', '견제한다'],
#   ['산사태', '막아라', '경북도', '산불', '피해지역', '장마철', '토사유출', '등', '위험도', '전수', '조사'],
#   ['폭염', '시달리다', '물에', '잠긴다', '기후', '위기', '최전선', '태평양', '섬나라들'],
#   ['폭염', '다음날', '폭설', '기온', '반전', '온실가스', '못', '줄이면', '더', '심화'],
#   ['제주서', '남국의', '정취', '자아내던', '워싱턴', '야자수', '뽑는다는데', '대체', '왜'],
#   ['침식피해', '부산', '송정해수욕장', '해양휴양공간', '변신'],
#   ['미얀마', '군부', '지진', '피해', '복구', '위해', '반군과', '휴전', '30일까지', '연장'],
#   ['35년', '만에', '처음', '일본으로', '건너간', '한국', '대표', '식재료', '일냈다'],
#   ['끓는', '바다에', '산호초', '84', '하얗게', '죽어가', '해양생물', '집', '먹이', '없어져'],
#   ['여행', '수요', '느는데', '항공기', '4대', '중', '1대는', '지연'],
#   ['김정은', '앞에서', '주머니', '손', '넣던', '그', '간부', '두달째', '자취', '감춰'],
#   ['기고', '한', '통의', '호우', '긴급재난문자', '에', '담긴', '의미'],
#   ['사설', '경북', '산불', '한', '달', '피해', '주민', '돌보는', '데', '소홀함', '없어야'],
#   ['대구시', '재난안전기동대', '선발', '초기', '대응', '강화'],
#   ['자퇴',
#    '농사',
#    '42세',
#    '유학',
#    '수석',
#    '졸업',
#    '쓸모',
#    '묻지',
#    '말고',
#    '공부하라',
#    '안혜리의',
#    '인생'],
#   ['태풍에', '간판', '피해', '없게', '영등포', '민관', '점검'],
#   ['사랑방', '연세대', '外'],
#   ['글로벌',
#    '현장을',
#    '가다',
#    '황인찬',
#    '158國',
#    '참가',
#    '문화',
#    '기술',
#    '올림픽',
#    '흥행',
#    '여부',
#    '7월',
#    '日선거',
#    '변수될',
#    '듯'],
#   ['경북', '산불', '발생', '한달인데', '이재민들', '고통은', '현재', '진행형'],
#   ['분열', '넘고', '통일', '향해', '700만', '재외동포', '염원', '모은다'],
#   ['필리핀', '민다나오섬', '다바오', '남동쪽', '해역', '규모', '6', '2', '지진'],
#   ['127m', '높이', '화순', '풍력발전기', '한밤중', '쿵', '빨대처럼', '꺾였다'],
#   ['교황선종', '아시아', '태평양', '비췄던', '등불', '프란치스코', '교황'],
#   ['히말라야', '적설량', '23년만', '최저', '20억명', '물', '안보', '위협'],
#   ['분홍돌고래', '180cm', '수달', '1m', '앵무새', '아마존이', '특별한', '이유'],
#   ['경상도',
#    '사유림이',
#    '90',
#    '인데',
#    '산불진화',
#    '임도',
#    '개설비',
#    '산주인',
#    '부담',
#    '산불',
#    '한',
#    '달'],
#   ['亞', '최대', '가톨릭', '국가', '필리핀', '고아가', '된', '것', '같다', '교황', '선종에', '비통'],
#   ['20억명', '위협한다는', '이곳', '충격', '근황', '23년', '만에', '최저', '수준'],
#   ['대구시', '재난안전기동대', '공무직근로자', '공개', '채용'],
#   ['산불', '등', '재난', '신속', '대응', '대구시', '재난안전기동대', '공개', '채용'],
#   ['영산강', '하구둑', '수위', '조절', '총력', '대응', '나섰다', '관계기관', '협약'],
#   ['김정은', '1호', '사업', '망신에', '격노', '최측근', '조용원이', '사라졌다'],
#   ['미국',
#    '현장',
#    '리포트',
#    '살',
#    '수도',
#    '지킬',
#    '수도',
#    '없는',
#    '집',
#    '주거',
#    '안정성',
#    '붕괴된',
#    '미국'],
#   ['기술',
#    '인구',
#    '기후',
#    '변화',
#    '대응',
#    '기술',
#    '인구',
#    '기후',
#    '3대',
#    '변화가',
#    '복지',
#    '미래',
#    '흔든다'],
#   ['단국대', '산불', '피해', '재학생', '위해', '특별장학금', '100만원', '지급'],
#   ['일본서', '완판된', '한국', '쌀', '현지', '소비자', '반응은'],
#   ['초미세먼지', '농도', '전남이', '가장', '낮아', '서울', '충북', '높아'],
#   ['대구시', '재난', '초동대처', '강화', '재난안전기동대', '선발'],
#   ['한덕수', '한미', '과학기술', '협력', '굳건', '원자력', '연구', '개발에', '집중', '투자할', '것'],
#   ['대구', '산림재난기동대', '확대', '개편', '재난안전기동대', '15명', '공개', '채용'],
#   ['미안마', '국민과', '함께', '금호건설', '지진', '피해', '지원'],
#   ['바람', '없는', '잔잔한', '날에', '엿가락처럼', '휜', '127m', '풍력발전기', '뭔일'],
#   ['산불', '한달', '여전히', '멈춘', '일상', '이재민', '현재진행형', '아픔'],
#   ['금호건설', '월드비전에', '미얀마', '지진', '피해복구', '후원금', '전달'],
#   ['경북', '산불', '발생', '한', '달', '이재민들', '고통은', '현재', '진행형'],
#   ['전남', '화학산', '127m', '풍력발전기', '엿가락처럼', '쓰러져'],
#   ['이상기후', '피해', '급증에', '농작물', '보험', '지원', '확대'],
#   ['2027년', '세계', '첫', '수자원위성', '쏜다', '北', '무단방류', '등', '실시간', '수해', '감시'],
#   ['글로벌', '아이', '재난', '외교'],
#   ['꽃가루', '미세먼지', '공습에', '눈물', '콧물', '줄줄', '오전', '외출은', '피하세요'],
#   ['엿가락처럼', '화순', '화학산', '풍력발전기', '꺾였다'],
#   ['포항지진', '태풍', '당시', '도움', '받은', '것', '되돌려줄', '때'],
#   ['우정과', '저항', '청춘의', '조각을', '맞추다'],
#   ['내일날씨', '전국에', '요란한', '비', '제주', '남해안', '폭우'],
#   ['현대',
#    '전기버스',
#    '일렉시티',
#    '유네스코',
#    '세계유산',
#    '日',
#    '야큐시마',
#    '달린다',
#    '현지에',
#    '5대',
#    '전달'],
#   ['필리핀', '하원의장', '교황', '아버지', '친구이자', '어둠', '속의', '등불', '추모'],
#   ['공원식', '전', '경북도부지사', '한국자유총연맹', '경북지부', '신임', '회장', '임명'],
#   ['묘장', '스님', '섭씨', '40도', '찜통', '더위', '지진', '피해', '미얀마', '구호', '손길', '절실'],
#   ['겨울이', '우울', '봄', '자살률', '더', '높아', '심장과', '마음은', '봄에', '더', '아프다'],
#   ['3494명',
#    '여전히',
#    '이재민',
#    '신세',
#    '더딘',
#    '복구에',
#    '잠',
# ...
#    '따르면',
#    '이날',
#    '아침',
#    '미얀마',
#    '중부에',
#    '위치한',
#    '작은',
#    '도시',
#    '메이크틸라',
#    '인근에는',
#    '지난달',
#    '28일',
#    '이후',
#    '가장',
#    '큰',
#    '규모의',
#    '여진인',
#    '규모',
#    '5',
#    '5의',
#    '지진이'],
#   ['경북도가',
#    '지난달',
#    '산불',
#    '피해로',
#    '산사태',
#    '발생',
#    '우려가',
#    '높아지면서',
#    '신속한',
#    '복구에',
#    '나선다',
#    '13일',
#    '경북도는',
#    '산림청',
#    '및',
#    '각',
#    '시군',
#    '산림조합',
#    '등',
#    '산림전문가로',
#    '구성된',
#    '피해조사반',
#    '정밀',
#    '조사',
#    '결과',
#    '응급',
#    '복구와',
#    '연내',
#    '복구가',
#    '필요한',
#    '곳',
#    '201개소와',
#    '항구복구',
#    '필요',
#    '지역',
#    '97개소를',
#    '확인했다고',
#    '밝혔다',
#    '이를',
#    '바탕으로',
#    '중앙',
#    '지방',
#    '합동조사반의',
#    '조사',
#    '확인을',
#    '거치면',
#    '이번',
#    '산불로',
#    '인한',
#    '산'],
#   ['아시아투데이',
#    '김시영',
#    '기자',
#    '서울',
#    '청량리',
#    '중심상권',
#    '아트포레스트청량리에',
#    '대형',
#    '한방병원',
#    '솔라시도한방병원',
#    '이',
#    '개원했다',
#    '솔라시도한방병원은',
#    '양',
#    '한방협진',
#    '체제로',
#    '가정의학과',
#    '전문의',
#    '침구과',
#    '한방내과',
#    '한방부인과',
#    '한방피부과',
#    '한방재활의학과',
#    '등을',
#    '진료한다',
#    '솔라시도한방병원은',
#    '교통사고',
#    '환자의',
#    '사고',
#    '휴유증',
#    '관리',
#    '및',
#    '척추',
#    '관절통증치료',
#    '수술',
#    '후',
#    '재활'],
#   ['올여름',
#    '부산',
#    '해운대해수욕장의',
#    '정식',
#    '개장',
#    '기간이',
#    '9월',
#    '중순까지로',
#    '연장된다',
#    '최고',
#    '기온이',
#    '30도를',
#    '웃도는',
#    '찜통더위가',
#    '가을까지',
#    '이어지는데다',
#    '일찌감치',
#    '안전요원이',
#    '철수한',
#    '해수욕장에서',
#    '인명사고까지',
#    '나는',
#    '상황에',
#    '대응하기',
#    '위한',
#    '조치다',
#    '가을폭염ㆍ인명사고에',
#    '길게',
#    '여는',
#    '海',
#    '13일',
#    '부산',
#    '해운대구에',
#    '따르면',
#    '올해',
#    '해운대해수욕장은',
#    '6월',
#    '21일부터',
#    '9월',
#    '1'],
#   ['응급',
#    '연내',
#    '복구',
#    '201곳',
#    '항구복구',
#    '97곳',
#    '안동',
#    '박천학',
#    '기자',
#    '지난달',
#    '경북지역',
#    '5개',
#    '시군을',
#    '휩쓴',
#    '괴물',
#    '산불',
#    '로',
#    '산사태',
#    '방지를',
#    '위해',
#    '복구가',
#    '필요한',
#    '지역이',
#    '300곳에',
#    '육박하는',
#    '것으로',
#    '나타났다',
#    '13일',
#    '경북도에',
#    '따르면',
#    '산림청',
#    '산불피해지',
#    '긴급',
#    '진단팀',
#    '과',
#    '경북도',
#    '시군',
#    '산림조합과',
#    '산림전문가로',
#    '구성된',
#    '피해조사반이',
#    '합동으로',
#    '산불',
#    '피해',
#    '지역을',
#    '정밀',
#    '조사한',
#    '결'],
#   ['경북',
#    '의성에서',
#    '시작해',
#    '영덕까지',
#    '확산한',
#    '산불로',
#    '전국',
#    '최대',
#    '송이',
#    '산지인',
#    '영덕의',
#    '송이산',
#    '70',
#    '가',
#    '소실된',
#    '것으로',
#    '나타났다',
#    '13일',
#    '영덕군에',
#    '따르면',
#    '지난달',
#    '25',
#    '26일',
#    '영덕',
#    '산불로',
#    '영덕읍',
#    '지품면',
#    '축산면',
#    '영해면',
#    '일대',
#    '송이산',
#    '4137',
#    '가',
#    '소실된',
#    '것으로',
#    '집계됐다',
#    '영덕',
#    '전체',
#    '피해',
#    '면적',
#    '8050',
#    '의',
#    '절반',
#    '가까운',
#    '규모다',
#    '영덕을',
#    '덮친',
#    '산불에',
#    '소나무',
#    '2만5'],
#   ['지난달',
#    '경북',
#    '북부지역을',
#    '휩쓸어',
#    '역대급',
#    '피해를',
#    '낳은',
#    '괴물',
#    '산불',
#    '의',
#    '불씨는',
#    '사그라들었지만',
#    '산사태나',
#    '오염물질의',
#    '하천',
#    '유입',
#    '등',
#    '2차',
#    '피해가',
#    '우려된고',
#    '있다',
#    '이에',
#    '경북도를',
#    '비롯한',
#    '산불',
#    '피해',
#    '지자체들은',
#    '2차',
#    '피해',
#    '우려가',
#    '높은',
#    '지역',
#    '현황을',
#    '조사하고',
#    '대책',
#    '마련에',
#    '나섰다',
#    '산불로',
#    '산림이',
#    '파괴된',
#    '상황에서',
#    '집중호우가',
#    '쏟아지면',
#    '산사태',
#    '위험이',
#    '크게',
#    '높아진다',
#    '산불',
#    '피'],
#   ['아시아투데이',
#    '배철완',
#    '기자',
#    '대구광역시가',
#    '여름철',
#    '고농도',
#    '오존',
#    '발생에',
#    '대응하기',
#    '위한',
#    '상황실',
#    '운영에',
#    '들어간다',
#    '대구시',
#    '보건환경연구원은',
#    '여름철',
#    '주요',
#    '대기오염물질인',
#    '오존을',
#    '실시간으로',
#    '모니터링하고',
#    '고농도',
#    '오존',
#    '발생',
#    '상황을',
#    '신속하게',
#    '알리기',
#    '위해',
#    '이달',
#    '15일부터',
#    '6개월간',
#    '대기환경상황실을',
#    '운영한다고',
#    '13일',
#    '밝혔다',
#    '이번',
#    '특별',
#    '상황실은',
#    '대구시에서',
#    '시행하고',
#    '있는',
#    '오존'],
#   ['아시아투데이',
#    '이진희',
#    '기자',
#    '36개국',
#    '국제',
#    '국회의장단이',
#    '한국수자원공사의',
#    '첨단',
#    '물관리',
#    '기술을',
#    '직접',
#    '견학하며',
#    '글로벌',
#    '협력',
#    '강화를',
#    '논의했다',
#    '수자원공사는',
#    '캄보디아',
#    '콜롬비아',
#    '등',
#    '36개국의',
#    '전',
#    '현직',
#    '국회의장으로',
#    '구성된',
#    '국제국회의장회의',
#    '대표단이',
#    '지난',
#    '11일',
#    '경기도',
#    '과천',
#    '한강유역본부',
#    '물종합상황실을',
#    '방문했다고',
#    '13일',
#    '밝혔다',
#    '이번',
#    '방문은',
#    '기후위기에',
#    '따른',
#    '글로벌',
#    '물'],
#   ['경북도는',
#    '지난달',
#    '22일부터',
#    '28일까지',
#    '발생한',
#    '초대형',
#    '산불',
#    '피해지역을',
#    '조사한',
#    '결과',
#    '201곳에',
#    '대한',
#    '응급',
#    '복구',
#    '필요성이',
#    '잠정',
#    '파악됐다고',
#    '13일',
#    '밝혔다',
#    '또한',
#    '산사태',
#    '등',
#    '2차',
#    '피해를',
#    '막기',
#    '위해',
#    '올해',
#    '안에',
#    '복구',
#    '작업이',
#    '필요한',
#    '곳',
#    '외에',
#    '연차별',
#    '복구가',
#    '필요한',
#    '지역은',
#    '97곳으로',
#    '확인됐다',
#    '경북도가',
#    '피해가',
#    '발생한',
#    '시',
#    '군',
#    '산림청',
#    '산림조합',
#    '및',
#    '산림전문가',
#    '등과',
#    '파악한'],
#   ['경북도는',
#    '지난',
#    '달',
#    '발생한',
#    '북동부지역',
#    '대형',
#    '산불로',
#    '복구가',
#    '필요한',
#    '곳이',
#    '300여곳에',
#    '이르는',
#    '것으로',
#    '나타났다고',
#    '13일',
#    '밝혔다',
#    '경북도에',
#    '따르면',
#    '지난',
#    '달',
#    '22일부터',
#    '28일까지',
#    '이어진',
#    '산불에',
#    '따른',
#    '5개',
#    '시군',
#    '피해에',
#    '대한',
#    '산림청',
#    '경북도',
#    '시군',
#    '산림조합',
#    '등의',
#    '정밀조사',
#    '결과',
#    '응급',
#    '복구와',
#    '연내',
#    '복구가',
#    '필요한',
#    '곳이',
#    '201개소',
#    '항구',
#    '복구가',
#    '필요한',
#    '지역이',
#    '97개소로'],
#   ['postech',
#    '이형주',
#    '교수팀',
#    '이산화질소',
#    '농도',
#    '500m',
#    '단위',
#    '정밀',
#    '분석',
#    '최근',
#    'postech',
#    '포항공과대학교',
#    '환경공학부',
#    '이형주',
#    '교수',
#    '통합과정',
#    '김나래',
#    '씨',
#    '연구팀은',
#    '인공위성',
#    '자료를',
#    '활용해',
#    '우리나라',
#    '전역의',
#    '이산화질소',
#    'no2',
#    '농도를',
#    '500m',
#    '고해상도',
#    '분석하고',
#    '사회경제적',
#    '수준에',
#    '따른',
#    '차이',
#    '분석에',
#    '성공했다',
#    '12일',
#    'postech에',
#    '따르면',
#    '이번',
#    '연구는'],
#   ['미국발',
#    '관세전쟁',
#    '여파로',
#    '세계',
#    '최대',
#    '올리브',
#    '생산국인',
#    '스페인이',
#    '미국',
#    '현지에서',
#    '올리브유를',
#    '생산하는',
#    '방안을',
#    '검토',
#    '중이라는',
#    '보도가',
#    '나왔다',
#    '로이터통신은',
#    '11일',
#    '현지시간',
#    '스페인',
#    '올리브유',
#    '생산업체',
#    '중',
#    '하나가',
#    '미국의',
#    '관세',
#    '전쟁에',
#    '대응하기',
#    '위해',
#    '미국',
#    '현지',
#    '재배를',
#    '고려하고',
#    '있다고',
#    '보도했다',
#    '스페인은',
#    '전',
#    '세계',
#    '올리브유의',
#    '40',
#    '를',
#    '생산하고',
#    '매년',
#    '약',
#    '18만',
#    '톤을',
#    '미국에'],
#   ['경기',
#    '광명시',
#    '신안산선',
#    '지하터널',
#    '공사현장',
#    '붕괴',
#    '사고가',
#    '발생한',
#    '지',
#    '만',
#    '하루가',
#    '지났으나',
#    '실종된',
#    '50대',
#    '근로자의',
#    '생사는',
#    '아직',
#    '확인되지',
#    '않고',
#    '있다',
#    '붕괴',
#    '사고가',
#    '발생한',
#    '경기도',
#    '광명시',
#    '신안산선',
#    '지하터널',
#    '공사',
#    '현장에서',
#    '12일',
#    '구조대원들이',
#    '실종자를',
#    '수색하고',
#    '있다',
#    '지난',
#    '11일',
#    '경기도',
#    '광명시',
#    '양지사거리',
#    '부근',
#    '신안산선',
#    '복선전철',
#    '제5',
#    '2공구',
#    '지하터널',
#    '공사',
#    '현장과',
#    '상부'],
#   ['로버트',
#    '파커',
#    '선정',
#    '올해의',
#    '인물',
#    '테누타',
#    '디',
#    '트리노',
#    '오너',
#    '안드레아',
#    '프란케티',
#    '2000년부터',
#    '화산재로',
#    '황폐화된',
#    '시칠리아',
#    '에트나',
#    '화산',
#    '파소피시아로',
#    '마을서',
#    '포도밭',
#    '복원',
#    '시작',
#    '100년',
#    '수령',
#    '토착',
#    '품종',
#    '네렐로',
#    '마스칼레제로',
#    '싱글빈야드',
#    '콘트라다',
#    '와인',
#    '선보여',
#    '평론가들',
#    '극찬',
#    '파소피시아로',
#    '마케팅',
#    '담당',
#    'gessica',
#    'di',
#    'vincenzo',
#    '최현태',
#    '기자',
#    '이리',
#    '저'],
#   ['부드럽고',
#    '감미로운',
#    '여름비처럼',
#    '여인은',
#    '장소의',
#    '고요에',
#    '잠겼다',
#    '사방의',
#    '모든',
#    '것이',
#    '고요하고',
#    '그',
#    '고요가',
#    '나무들에게서',
#    '온다는',
#    '것을',
#    '알아차렸다',
#    '고요는',
#    '나무의',
#    '일부이기',
#    '때문이다',
#    '다이애나',
#    '베리스퍼드',
#    '크로거의',
#    '세계숲',
#    '무시무시하고',
#    '구슬펐던',
#    '일주일',
#    '땅과',
#    '하늘',
#    '사이가',
#    '온통',
#    '비명으로',
#    '가득',
#    '찬',
#    '것',
#    '같았다',
#    '의성에서',
#    '시작된',
#    '불길은',
#    '걷잡을',
#    '수',
#    '없이',
#    '번져',
#    '최악의',
#    '산불'],
#   ['1',
#    '넌',
#    '이',
#    '제품이',
#    '될',
#    '거라고',
#    '생각하니',
#    '2013년',
#    '어느',
#    '날',
#    '채진희',
#    'lg전자',
#    '상품기획',
#    '담당',
#    '대리',
#    '현',
#    '리빙솔루션se팀',
#    '팀장',
#    '에게',
#    '그의',
#    '사수가',
#    '물었다',
#    '그',
#    '전해에',
#    '이직해',
#    '오고',
#    '나서',
#    '이',
#    '제품',
#    '기획을',
#    '맡은',
#    '채',
#    '대리가',
#    '무슨',
#    '자신감이었는지',
#    '말했다',
#    '네',
#    '무조건',
#    '뜰',
#    '거라고',
#    '생각해요',
#    '시간문제에요',
#    '사수는',
#    '그래',
#    '네가',
#    '그렇게',
#    '생각하면',
#    '다행이다',
#    '좋겠다'],
#   ['12일',
#    '오전',
#    '제주와',
#    '중부지방',
#    '서해안부터',
#    '강수가',
#    '시작돼',
#    '오후',
#    '전국으로',
#    '확산한',
#    '뒤',
#    '오는',
#    '월요일까지',
#    '이어지겠다',
#    '주말',
#    '기온은',
#    '평년기온',
#    '위아래로',
#    '요동치겠다',
#    '이날',
#    '오전',
#    '제주와',
#    '인천',
#    '경기',
#    '충남',
#    '북부',
#    '서해안부터',
#    '비가',
#    '오겠다',
#    '오후',
#    '전국에',
#    '확대된',
#    '비는',
#    '밤까지',
#    '이어지겠다',
#    '강원',
#    '동해안과',
#    '충남내륙',
#    '전북',
#    '동부',
#    '영남은',
#    '오는',
#    '13일',
#    '새벽까지',
#    '비가',
#    '계속',
#    '오'],
#   ['꽃가루로',
#    '인해',
#    '재채기',
#    '콧물',
#    '눈',
#    '가려움증으로',
#    '고생하는',
#    '이들이',
#    '늘면서',
#    '증상',
#    '완화에',
#    '도움',
#    '되는',
#    '지압법이',
#    '주목받고',
#    '있다',
#    '봄꽃이',
#    '만개함에',
#    '따라',
#    '눈에',
#    '잘',
#    '보이지',
#    '않는',
#    '꽃가루도',
#    '대기',
#    '중에',
#    '퍼지기',
#    '시작했다',
#    '꽃가루는',
#    '알레르기',
#    '환자들에게',
#    '반갑지',
#    '않은',
#    '손님이다',
#    '꽃가루는',
#    '꽃망울이',
#    '터지면서',
#    '발생하는',
#    '미세한',
#    '가루다',
#    '이것이',
#    '호흡기를',
#    '통해',
#    '흡입되었을',
#    '때',
#    '알'],
#   ['미국과',
#    '멕시코',
#    '간',
#    '물',
#    '전쟁',
#    '이',
#    '다시',
#    '수면',
#    '위로',
#    '떠오르고',
#    '있다',
#    '도널드',
#    '트럼프',
#    '미국',
#    '대통령이',
#    '멕시코를',
#    '향해',
#    '남부',
#    '텍사스에',
#    '물을',
#    '공급하지',
#    '않으면',
#    '관세와',
#    '제재를',
#    '부과하겠다고',
#    '위협했다',
#    '미국과',
#    '멕시코',
#    '간',
#    '국경',
#    '강물',
#    '공급을',
#    '둘러싼',
#    '갈등이',
#    '도널드',
#    '트럼프',
#    '1기',
#    '정부',
#    '때에',
#    '이어',
#    '2기',
#    '정부',
#    '들어서',
#    '재점화하고',
#    '있다',
#    '지난달',
#    '23일',
#    '현지시간',
#    '미국',
#    '텍사스주'],
#   ['잠에서',
#    '깨어',
#    '제일',
#    '먼저',
#    '하는',
#    '일이',
#    '기도였으면',
#    '좋겠지만',
#    '팔을',
#    '뻗어',
#    '베개',
#    '옆에',
#    '놓인',
#    '스마트폰부터',
#    '집어',
#    '든다',
#    '오늘은',
#    '날이',
#    '맑은지',
#    '흐린지',
#    '비가',
#    '오고',
#    '바람이',
#    '부는지도',
#    '볼',
#    '테지만',
#    '그보다는',
#    '미세먼지와',
#    '초미세먼지를',
#    '나타내는',
#    '글씨의',
#    '색깔에',
#    '시선이',
#    '먼저',
#    '간다',
#    '열에',
#    '아홉은',
#    '실망이다',
#    '주황색',
#    '나쁨',
#    '이',
#    '일상다반사기',
#    '때문이다',
#    '그나마',
#    '초록색',
#    '보통',
#    '이면',
#    '다행이라',
#    '여기고',
#    '창'],
#   ['울릉도에서는',
#    '4',
#    '5월',
#    '봄걷이',
#    '가',
#    '본격적으로',
#    '시작된다',
#    '육지에서는',
#    '가을에',
#    '수확하는',
#    '가을걷이지만',
#    '울릉도에서는',
#    '참고비',
#    '명이',
#    '부지깽이',
#    '전호',
#    '삼나물',
#    '섬엉겅퀴',
#    '미역취',
#    '등',
#    '지천에서',
#    '돋아나는',
#    '봄나물을',
#    '채취하느라',
#    '온',
#    '섬이',
#    '떠들썩해진다',
#    '경남',
#    '통영에서는',
#    '도다리쑥국이',
#    '봄의',
#    '대표',
#    '음식이라면',
#    '울릉도에서는',
#    '삼겹살',
#    '한',
#    '점',
#    '넣고',
#    '싸',
#    '먹는',
#    '갓',
#    '캔',
#    '전호나물이',
#    '향긋한',
#    '봄',
#    '내음을',
#    '전'],
#   ['개st하우스는',
#    '위기의',
#    '동물이',
#    '가족을',
#    '만날',
#    '때까지',
#    '함께하는',
#    '유기동물',
#    '기획',
#    '취재입니다',
#    '사연',
#    '속',
#    '동물에게',
#    '도움을',
#    '주고',
#    '싶다면',
#    '유튜브',
#    '개st하우스',
#    '를',
#    '구독해주세요',
#    '산불',
#    '속에서',
#    '많은',
#    '동물들이',
#    '대피하지',
#    '못했습니다',
#    '주인이',
#    '있던',
#    '노랑이랑',
#    '말순이도',
#    '마찬가지였죠',
#    '견주들은',
#    '노랑이와',
#    '말순이를',
#    '마을',
#    '외곽에',
#    '묶어두고',
#    '떠나야',
#    '했습니다',
#    '반려견은',
#    '대피소에',
#    '함께',
#    '들어'],
#   ['경기',
#    '광명시',
#    '일직동',
#    '신안산선',
#    '지하',
#    '터널',
#    '공사장',
#    '붕괴',
#    '사고로',
#    '고립된',
#    '작업자',
#    '계측',
#    '직원',
#    '1명이',
#    '밤샘',
#    '수색작업',
#    '끝에',
#    '구조됐다',
#    '경찰과',
#    '소방당국',
#    '설명을',
#    '들어보면',
#    '전날',
#    '오후',
#    '3시13분께',
#    '발생한',
#    '사고로',
#    '실종됐던',
#    '하청업체',
#    '소속',
#    '20대',
#    '노동자',
#    'ㄱ씨가',
#    '사고',
#    '발생',
#    '13시간',
#    '만인',
#    '12일',
#    '새벽',
#    '4시27분께',
#    '잔해',
#    '더미에서',
#    '빠져나왔다',
#    'ㄱ씨는',
#    '검사를',
#    '위해',
#    '병원으로',
#    '실려갔으'],
#   ['황신혜',
#    '왼쪽',
#    '故',
#    '김수미',
#    'lg헬로비전',
#    'tv조선',
#    '제공',
#    '배우',
#    '고',
#    '故',
#    '김수미는',
#    '살아생전',
#    '손맛이',
#    '좋기로',
#    '유명했다',
#    'tvn',
#    'olive',
#    '수미네',
#    '반찬',
#    'sbs',
#    'plus',
#    '밥은',
#    '먹고',
#    '다니냐',
#    '등',
#    '예능',
#    '프로그램을',
#    '통해서도',
#    '김수미의',
#    '음식',
#    '솜씨는',
#    '증명된',
#    '바',
#    '있다',
#    '그는',
#    '김치',
#    '반찬',
#    '등을',
#    '판매하는',
#    '음식',
#    '사업에도',
#    '도전해',
#    '홈쇼핑',
#    '완판',
#    '신화를',
#    '쓴',
#    '주인공이기도',
#    '하다'],
#   ['한국지능정보사회진흥원',
#    '원장',
#    '황종성',
#    '이하',
#    'nia',
#    '은',
#    '과학기술정보통신부의',
#    '디지털',
#    '트윈',
#    '기반',
#    '도시침수',
#    '스마트',
#    '대응',
#    '시스템',
#    '실증',
#    '사업',
#    '을',
#    '전담기관으로서',
#    '22년부터',
#    '24년까지',
#    '성공적으로',
#    '완료했다고',
#    '밝혔다',
#    '이를',
#    '통해',
#    '광주',
#    '포항',
#    '창원',
#    '등',
#    '실증',
#    '지역에',
#    '도시침수를',
#    '입체적이고',
#    '선제적으로',
#    '예측',
#    '대응할',
#    '수',
#    '있는',
#    '체계를',
#    '구축하였으며',
#    '시스템',
#    '확산을',
#    '위한',
#    '표'],
#   ['인도',
#    '동부와',
#    '네팔',
#    '일부',
#    '지역에',
#    '쏟아진',
#    '폭우로',
#    '약',
#    '100명이',
#    '목숨을',
#    '잃었다',
#    '11일',
#    '로이터통신에',
#    '따르면',
#    '네팔과',
#    '접한',
#    '인도',
#    '동부',
#    '비하르주에서는',
#    '9일',
#    '이후',
#    '폭우와',
#    '벼락으로',
#    '인해',
#    '64명이',
#    '사망했다',
#    '인도',
#    '내에서',
#    '가장',
#    '인구가',
#    '많은',
#    '우타르프라데시주에서도',
#    '20명',
#    '이상이',
#    '숨졌다',
#    '인접한',
#    '네팔',
#    '국가재난관리청은',
#    '폭우와',
#    '벼락으로',
#    '네팔에서',
#    '8명',
#    '이상이',
#    '사망했다',
#    '고'],
#   ['백두산의',
#    '북한',
#    '영토가',
#    '유네스코',
#    '세계지질공원에',
#    '등재됐다',
#    '지난해',
#    '중국',
#    '영토에',
#    '속하는',
#    '백두산',
#    '일부분이',
#    '지정된',
#    '이후',
#    '이번에',
#    '북한',
#    '쪽',
#    '백두산도',
#    '인정되면서',
#    '백두산',
#    '전체가',
#    '세계지질공원이',
#    '됐다',
#    '유네스코',
#    '집행이사회는',
#    '10일',
#    '현지시간',
#    '북한의',
#    '백두산을',
#    '세계지질공원으로',
#    '승인했다고',
#    '밝혔다',
#    '이로써',
#    '북한은',
#    '처음으로',
#    '세계지질공원을',
#    '보유하게',
#    '됐다',
#    '중국은',
#    '2020년',
#    '창바이'],
#   ['아시아투데이',
#    '배철완',
#    '기자',
#    '대구신용보증재단은',
#    '최근',
#    '초대형',
#    '산불로',
#    '큰',
#    '피해를',
#    '입은',
#    '경북',
#    '영덕군에',
#    '복구',
#    '지원과',
#    '이재민',
#    '구호를',
#    '위한',
#    '성금',
#    '2000만원을',
#    '전달했다고',
#    '11일',
#    '밝혔다',
#    '이번',
#    '성금은',
#    '대구신보',
#    '임직원들이',
#    '자발적으로',
#    '모금한',
#    '1000만원과',
#    '기관',
#    '자체',
#    '재원',
#    '1000만원을',
#    '합해',
#    '마련된',
#    '것으로',
#    '영덕복지재단을',
#    '통해',
#    '영덕군에',
#    '전달됐다',
#    '해당',
#    '성금은',
#    '산불',
#    '피해지역'],
#   ['국제구호개발',
#    'ngo',
#    '월드쉐어',
#    '이사장',
#    '최순자',
#    '가',
#    '미얀마',
#    '지진',
#    '긴급구호',
#    '활동에',
#    '착수했다고',
#    '11일',
#    '밝혔다',
#    '월드쉐어는',
#    '재미얀마',
#    '한인회와',
#    '협력하여',
#    '지난',
#    '9일부터',
#    '10일까지',
#    '미얀마',
#    '네피도와',
#    '만달레이',
#    '지역에서',
#    '긴급구호',
#    '활동을',
#    '전개하며',
#    '지진피해',
#    '주민',
#    '1만여',
#    '명에게',
#    '긴급',
#    '식량과',
#    '생필품을',
#    '전달했다',
#    '이번',
#    '긴급구호',
#    '활동은',
#    '지진피해',
#    '이재민들에게',
#    '가장',
#    '필요한',
#    '물품을',
#    '사'],
#   ['기후대응숲',
#    '도시바람길숲',
#    '자녀안심',
#    '그린숲',
#    'brt',
#    '간선급행버스체계',
#    '정류장',
#    '자연숲',
#    '부산',
#    '도심',
#    '안',
#    '작은',
#    '숲들이',
#    '보다',
#    '다양해진다',
#    '산이나',
#    '수목원',
#    '등만이',
#    '아니라',
#    '간선도로',
#    '학교',
#    '주변',
#    '공단이나',
#    '아파트',
#    '둘레',
#    '등에',
#    '소규모',
#    '기능성',
#    '숲들이',
#    '선보인다',
#    '부산시는',
#    '110억원을',
#    '투입',
#    '올해',
#    '안에',
#    '시민들과',
#    '가까운',
#    '생활권',
#    '공간에',
#    '자연',
#    '삼림보다는',
#    '작지만',
#    '미세먼지'],
#   ['한국지능정보사회진흥원',
#    'nia',
#    '은',
#    '과학기술정보통신부의',
#    '디지털',
#    '트윈',
#    '기반',
#    '도시',
#    '침수',
#    '스마트',
#    '대응',
#    '시스템',
#    '실증',
#    '사업',
#    '을',
#    '성공적으로',
#    '완료했다고',
#    '11일',
#    '밝혔다',
#    '디지털',
#    '트윈',
#    '기반',
#    '도시',
#    '침수',
#    '실증사업은',
#    '급격한',
#    '기후',
#    '변화',
#    '등',
#    '복합적인',
#    '요인으로',
#    '인한',
#    '침수',
#    '피해',
#    '증가에',
#    '대응하기',
#    '위해',
#    '2022년부터',
#    '추진됐다',
#    '디지털',
#    '트윈',
#    '인공지능',
#    '사물인터넷',
#    '등',
#    '첨단기술을',
#    '활용'],
#   ['백두산의',
#    '북한',
#    '영토가',
#    '유네스코',
#    'unesco',
#    '세계지질공원에',
#    '등재됐다',
#    '유네스코',
#    '집행이사회가',
#    '10일',
#    '현지시각',
#    '북한의',
#    '백두산을',
#    '세계지질공원으로',
#    '등재하는',
#    '데',
#    '승인했다고',
#    '연합뉴스가',
#    '보도했다',
#    '유네스코는',
#    '지질학적',
#    '가치를',
#    '지닌',
#    '지역을',
#    '보존하고',
#    '관리하기',
#    '위해',
#    '세계지질공원으로',
#    '지정한다',
#    '지난해',
#    '중국이',
#    '백두산의',
#    '중국',
#    '영토',
#    '부분을',
#    '창바이산',
#    '長白山',
#    '장백산',
#    '이라는',
#    '이름'],
#   ['이번',
#    '주말',
#    '전국에',
#    '강한',
#    '봄비가',
#    '예고됐다',
#    '돌풍과',
#    '천둥',
#    '번개를',
#    '동반한',
#    '요란한',
#    '비가',
#    '쏟아질',
#    '것으로',
#    '전망됐다',
#    '세찬',
#    '비에',
#    '봄꽃도',
#    '대부분',
#    '떨어질',
#    '것으로',
#    '보인다',
#    '기상청에',
#    '따르면',
#    '12일',
#    '중국',
#    '상하이',
#    '부근에서',
#    '발달한',
#    '저기압이',
#    '우리나라를',
#    '통과하며',
#    '전국에',
#    '비가',
#    '내리겠다',
#    '비는',
#    '12일',
#    '오전',
#    '제주에서',
#    '시작돼',
#    '오후에',
#    '전국으로',
#    '확대되겠다',
#    '비는',
#    '12일',
#    '밤',
#    '대부분',
#    '그치'],
#   ['서울',
#    '성북구',
#    '지역자율방재단이',
#    '영남',
#    '지역',
#    '산불',
#    '피해',
#    '주민을',
#    '돕기',
#    '위해',
#    '모금한',
#    '성금',
#    '201만원을',
#    '성북구에',
#    '전달했다고',
#    '11일',
#    '밝혔다',
#    '성금',
#    '전달식에는',
#    '이승로',
#    '성북구청장을',
#    '비롯해',
#    '자율방재단',
#    '관계자들이',
#    '참석했다',
#    '전달된',
#    '성금은',
#    '피해',
#    '주민의',
#    '생활',
#    '안정과',
#    '복구',
#    '활동에',
#    '사용될',
#    '예정이다',
#    '성북구',
#    '지역자율방재단은',
#    '재난',
#    '예방과',
#    '대응을',
#    '위한',
#    '민간',
#    '조직으로',
#    '평소',
#    '재난',
#    '취약'],
#   ...])

# %%
# 전처리 + 토큰화 : 소문자 통일, 형태소단위 토큰화

# gensim 이용해서 embedding model 학습.

# 결과 확인 -> 유사도 검사
