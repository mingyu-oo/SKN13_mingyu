# %%
import pandas as pd

# CSV 파일 불러오기
df = pd.read_csv("2025_06_07.csv", encoding="cp949")

# %%
df
# Out:
#           NO              시군구    번지   도로조건  계약면적(㎡) 전월세구분    계약년월  계약일  \
# 0          1  경기도 성남시 분당구 정자동    4*  25m미만    50.00    월세  202507    5
# 1          2  경기도 수원시 팔달구 우만동    5*   8m미만    20.00    전세  202507    5
# 2          3  경기도 수원시 팔달구 인계동  1***   8m미만    21.00    월세  202507    5
# 3          4  경기도 성남시 수정구 태평동  3***   8m미만    25.00    월세  202507    5
# 4          5     경기도 오산시 내삼미동   8**  12m미만    55.00    전세  202507    5
# ...      ...              ...   ...    ...      ...   ...     ...  ...
# 23979  23980     경상남도 김해시 삼계동  1***  12m미만    40.00    월세  202506    8
# 23980  23981      충청남도 논산시 내동  1***  25m이상    33.00    월세  202506    8
# 23981  23982      경기도 시흥시 대야동   5**  12m미만    49.58    전세  202506    8
# 23982  23983     전라남도 여수시 문수동   2**  12m미만    32.40    월세  202506    8
# 23983  23984    부산광역시 금정구 금사동    2*   8m미만    93.70    월세  202506    8
#
#       보증금(만원)  월세금(만원)    건축년도        도로명           계약기간 계약구분 갱신요구권 사용  \
# ...

# %%
df.isna().sum()
# Out:
# NO                  0
# 시군구                 0
# 번지                  0
# 도로조건                0
# 계약면적(㎡)             0
# 전월세구분               0
# 계약년월                0
# 계약일                 0
# 보증금(만원)             0
# 월세금(만원)             0
# 건축년도             1430
# 도로명                61
# 계약기간                0
# 계약구분                0
# 갱신요구권 사용            0
# 종전계약 보증금(만원)    21777
# 종전계약 월세(만원)     21777
# 주택유형                0
# dtype: int64
